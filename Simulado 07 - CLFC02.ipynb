# %%
## SIMULADO 7 - AWS Cloud Practitioner (CLF-C02) ##

Por Marcelo Avelino

---

**Pergunta 1:**
Uma empresa migrou suas cargas de trabalho para a AWS. A empresa deseja adotar a AWS em grande escala e operar de maneira mais eficiente e segura. Qual serviço ou estrutura da AWS a empresa deve usar para suporte operacional?
- a) AWS Support
- b) **Serviços Gerenciados da AWS (AMS)**
- c) Estrutura AWS Well-Architected
- d) Estrutura de Adoção da Nuvem AWS (AWS CAF)

**Explicação:**
- O AWS Support fornece suporte técnico e orientação, mas não oferece os serviços gerenciados abrangentes necessários para a operação eficiente e segura em grande escala.

**Correta:**
- **Serviços Gerenciados da AWS (AMS)**: Os Serviços Gerenciados da AWS (AMS) ajudam as empresas a operar de maneira mais eficiente e segura na AWS. Eles fornecem suporte operacional abrangente, incluindo gerenciamento de infraestrutura, monitoramento contínuo, aplicação de patches e otimização de custos. AMS permite que as empresas se concentrem em seus negócios principais enquanto a AWS gerencia a infraestrutura subjacente.

**Incorretas:**
- Estrutura AWS Well-Architected: A AWS Well-Architected Framework ajuda as empresas a projetar, operar e melhorar cargas de trabalho seguras, eficientes e resilientes, mas não fornece suporte operacional contínuo.
- Estrutura de Adoção da Nuvem AWS (AWS CAF): A AWS CAF fornece orientações estratégicas e ajuda as empresas a desenvolverem uma estratégia de adoção da nuvem, mas não oferece suporte operacional direto.

---

**Pergunta 2:**
Uma empresa deseja gerenciar serviços de TI implantados e governar sua infraestrutura como modelos de código (IaC). Qual serviço da AWS atenderá a esse requisito?
- a) AWS Resource Explorer (Explorador de Recursos da AWS)
- b) **AWS Service Catalog (Catálogo de Serviços da AWS)**
- c) AWS Systems Manager (Gerenciador de Sistemas da AWS)
- d) AWS Organizations (Organizações da AWS)

**Explicação:**
- **AWS Resource Explorer**: Esta opção está incorreta porque o AWS Resource Explorer é usado para procurar e visualizar recursos AWS em todas as regiões da AWS, mas não é especificamente voltado para gerenciar ou governar infraestrutura como código (IaC).

**Correta:**
- **AWS Service Catalog**: Esta é a resposta correta porque o AWS Service Catalog permite às organizações criar e gerenciar catálogos de serviços de TI que são aprovados para uso na AWS. Ele ajuda a governar a infraestrutura como código (IaC) ao permitir que as empresas padronizem as implementações, assegurando que apenas serviços aprovados sejam utilizados. Isso facilita a gerência e a governança dos serviços de TI implantados.

**Incorretas:**
- AWS Systems Manager: Esta opção está incorreta porque o AWS Systems Manager é um serviço que fornece uma visão unificada de seus recursos AWS, facilitando o gerenciamento operacional, mas não é especificamente voltado para governar infraestrutura como código (IaC)
- AWS Organizations: Esta opção está incorreta porque o AWS Organizations é usado para gerenciar várias contas AWS em uma organização, fornecendo controle centralizado sobre políticas de segurança e conformidade, mas não oferece funcionalidades específicas para gerenciar infraestrutura como código (IaC)

---

**Pergunta 3:**
A elasticidade na Nuvem AWS refere-se a qual das opções a seguir? (Escolha dois.)
- a) **The ability to rightsize resources as demand shifts (A capacidade de dimensionar corretamente os recursos conforme a demanda muda)**
- b) The pay-as-you-go billing model (O modelo de cobrança paga conforme o uso)
- c) **How easily resources can be procured when they are needed (Quão facilmente os recursos podem ser adquiridos quando necessário)**
- d) The maximum amount of RAM an Amazon EC2 instance can use (A quantidade máxima de RAM que uma instância Amazon EC2 pode usar)
- e) How quickly an Amazon EC2 instance can be restarted (Quão rapidamente uma instância Amazon EC2 pode ser reiniciada)

**Explicação:**
**Corretas:**
- **The ability to rightsize resources as demand shifts (A capacidade de dimensionar corretamente os recursos conforme a demanda muda)**: A elasticidade refere-se à capacidade de aumentar ou diminuir os recursos de TI conforme necessário para atender à demanda. Isso inclui dimensionar corretamente os recursos para otimizar custos e desempenho conforme a carga de trabalho varia.
- **How easily resources can be procured when they are needed (Quão facilmente os recursos podem ser adquiridos quando necessário)**: A elasticidade também envolve a facilidade com que os recursos podem ser provisionados ou liberados conforme necessário. Isso permite que as empresas respondam rapidamente a mudanças na demanda, garantindo que tenham a capacidade adequada para suas necessidades.

**Incorretas:**
- The pay-as-you-go billing model (O modelo de cobrança paga conforme o uso): Embora o modelo de cobrança paga conforme o uso seja uma característica importante da computação em nuvem, ele está mais relacionado à flexibilidade financeira do que à elasticidade operacional dos recursos.
- The maximum amount of RAM an Amazon EC2 instance can use (A quantidade máxima de RAM que uma instância Amazon EC2 pode usar): A quantidade máxima de RAM que uma instância EC2 pode usar é uma característica de dimensionamento vertical, não necessariamente relacionada à elasticidade, que geralmente envolve dimensionamento horizontal (adicionando ou removendo instâncias)
- How quickly an Amazon EC2 instance can be restarted (Quão rapidamente uma instância Amazon EC2 pode ser reiniciada): A rapidez com que uma instância Amazon EC2 pode ser reiniciada está relacionada à disponibilidade e recuperação, mas não define diretamente a elasticidade.

---

**Pergunta 4:**
Uma empresa deseja provisionar e gerenciar sua infraestrutura da AWS usando as linguagens de programação comuns TypeScript, Python, Java e .NET. Qual serviço da AWS atenderá a esse requisito?
- a) AWS CLI
- b) AWS CodeBuild
- c) AWS CloudFormation
- d) **AWS Cloud Development Kit (AWS CDK)**

**Explicação:**
**Correta:**
- **AWS Cloud Development Kit (AWS CDK)**: O AWS CDK é uma estrutura de código aberto que permite aos desenvolvedores definir a infraestrutura da nuvem da AWS usando linguagens de programação familiares como TypeScript, Python, Java e .NET. Ele oferece uma abordagem baseada em código para provisionar e gerenciar recursos da AWS, permitindo que os desenvolvedores usem suas habilidades de programação existentes.

**Incorretas:**
- AWS CLI: A AWS Command Line Interface (CLI) é uma ferramenta que permite interagir com os serviços da AWS a partir da linha de comando, mas não é uma estrutura de programação para definir infraestrutura usando linguagens de programação.
- AWS CodeBuild: O AWS CodeBuild é um serviço de integração contínua que compila o código-fonte, executa testes e produz pacotes de software prontos para implantação, mas não é usado para definir e gerenciar infraestrutura como código.
- AWS CloudFormation: O AWS CloudFormation é um serviço que permite modelar e provisionar recursos da AWS usando arquivos de texto JSON ou YAML, mas não oferece suporte direto para linguagens de programação como TypeScript, Python, Java e .NET.

---

**Pergunta 5:**
Uma empresa está usando o Nível Gratuito da AWS para vários serviços AWS em uma aplicação.

O que acontecerá se o período de uso do Nível Gratuito expirar ou se o uso da aplicação exceder os limites de uso do Nível Gratuito?
- a) A empresa será cobrada pelos serviços consumidos durante o período do Nível Gratuito, além de cobranças adicionais pelo consumo de serviços após o período do Nível Gratuito
- b) O Suporte da AWS entrará em contato com a empresa para configurar cobranças de serviço padrão
- c) **A empresa será cobrada pelas taxas padrão de serviço pay-as-you-go pelo uso que exceder o uso do Nível Gratuito**
- d) A conta AWS da empresa será congelada e poderá ser reiniciada após o estabelecimento de um plano de pagamento

**Explicação:**
**Correta:**
- **A empresa será cobrada pelas taxas padrão de serviço pay-as-you-go pelo uso que exceder o uso do Nível Gratuito**: Quando o período de uso do Nível Gratuito expirar ou se o uso da aplicação exceder os limites do Nível Gratuito, a empresa será cobrada pelas taxas padrão de serviço pay-as-you-go (pague conforme o uso) da AWS para qualquer uso que exceda o uso do Nível Gratuito. Não há contato prévio do Suporte da AWS ou congelamento da conta devido ao excedente do Nível Gratuito. A cobrança é automática e baseada no uso real dos serviços AWS.

**Incorretas:**
- A empresa será cobrada pelos serviços consumidos durante o período do Nível Gratuito, além de cobranças adicionais pelo consumo de serviços após o período do Nível Gratuito: Incorreta. Durante o período do Nível Gratuito, a empresa não é cobrada pelos serviços que estão dentro dos limites do Nível Gratuito. Somente o uso que exceder os limites será cobrado.
- O Suporte da AWS entrará em contato com a empresa para configurar cobranças de serviço padrão: Incorreta. O Suporte da AWS não entra em contato para configurar cobranças. As cobranças são automáticas

---

**Pergunta 6**

Qual é o propósito de ter um gateway de internet dentro de uma VPC?

a) Para criar uma conexão VPN com a VPC  
b) **Para permitir a comunicação entre a VPC e a internet**  
c) Para balancear a carga do tráfego da internet entre instâncias Amazon EC2  
d) Para impor restrições de largura de banda no tráfego da internet  

**Explicação:**
**Correta:**
- **Para permitir a comunicação entre a VPC e a internet**:
  - Um gateway de internet dentro de uma VPC permite a comunicação entre a VPC e a internet. Ele fornece uma rota para o tráfego de entrada e saída da internet para os recursos dentro da VPC, como instâncias EC2.

**Incorretas:**
- Para criar uma conexão VPN com a VPC:
  - A criação de uma conexão VPN com a VPC é realizada usando um gateway de VPN, não um gateway de internet.
- Para balancear a carga do tráfego da internet entre instâncias Amazon EC2:
  - O balanceamento de carga do tráfego da internet é realizado por um Elastic Load Balancer (ELB), não por um gateway de internet.
- Para impor restrições de largura de banda no tráfego da internet:
  - Um gateway de internet não é usado para impor restrições de largura de banda; ele apenas facilita a conectividade com a internet.

---

**Pergunta 7**

Uma empresa deseja criar painéis do Amazon QuickSight semanalmente usando seus dados de faturamento. Qual recurso ou ferramenta da AWS a empresa pode usar para atender a esses requisitos?

a) Orçamentos da AWS  
b) Explorador de custos da AWS  
c) **Relatório de custos e uso da AWS**  
d) Detecção de anomalias de custo da AWS  

**Explicação:**
**Correta:**
- **Relatório de custos e uso da AWS**:
  - O AWS Cost and Usage Report (CUR) fornece informações detalhadas sobre o uso e os custos dos serviços da AWS. Ele permite que as empresas exportem seus dados de faturamento detalhados para um bucket do Amazon S3. Esses dados podem ser usados pelo Amazon QuickSight para criar painéis e visualizações semanais, ajudando a monitorar e analisar os custos.

**Incorretas:**
- Orçamentos da AWS:
  - O AWS Budgets ajuda a criar orçamentos e a monitorar seus custos e uso da AWS, mas não é projetado para criar painéis detalhados no Amazon QuickSight.
- Explorador de custos da AWS:
  - O AWS Cost Explorer oferece uma interface para visualizar e analisar seus custos e uso, mas não fornece a granularidade necessária para criar painéis semanais detalhados no Amazon QuickSight.
- Detecção de anomalias de custo da AWS:
  - O AWS Cost Anomaly Detection é usado para identificar gastos anômalos, mas não fornece a capacidade de criar painéis detalhados usando o Amazon QuickSight.

---

**Pergunta 8**

Quais serviços ou recursos da AWS oferecem alta disponibilidade e baixa latência, permitindo failover em diferentes regiões da AWS? (Escolha dois.)

a) Balanceador de carga de rede  
b) **Rota Amazônica 53**  
c) Aceleração de transferência do Amazon S3  
d) **Acelerador Global AWS**  
e) Balanceador de carga de aplicativo  

**Explicação:**
**Corretas:**
- **Rota Amazônica 53**:
  - Amazon Route 53 é um serviço de sistema de nomes de domínio (DNS) escalável e altamente disponível. Ele permite o failover entre diferentes regiões da AWS, proporcionando alta disponibilidade e baixa latência ao direcionar o tráfego dos usuários para endpoints de aplicação que estejam geograficamente mais próximos deles.
- **Acelerador Global AWS**:
  - AWS Global Accelerator é um serviço de rede que melhora a disponibilidade e a performance das suas aplicações globais ao rotear o tráfego dos usuários para endpoints de aplicação mais próximos baseados na latência. Ele permite o failover automático entre regiões, garantindo alta disponibilidade.

**Incorretas:**
- Balanceador de carga de rede:
  - Network Load Balancer é usado para distribuir tráfego dentro de uma única região da AWS, oferecendo alta disponibilidade e baixa latência, mas não oferece failover entre diferentes regiões.
- Aceleração de transferência do Amazon S3:
  - S3 Transfer Acceleration melhora a velocidade de upload para buckets do Amazon S3, utilizando pontos de presença da AWS globalmente distribuídos, mas não oferece failover entre regiões.
- Balanceador de carga de aplicativo:
  - Application Load Balancer (ALB) distribui tráfego dentro de uma única região da AWS, oferecendo alta disponibilidade e baixa latência dentro dessa região, mas não oferece failover entre diferentes regiões.

---

**Pergunta 9**

Uma empresa deseja receber uma notificação quando um limite de custo específico da AWS for atingido. Quais serviços ou ferramentas da AWS a empresa pode usar para atender a esse requisito? (Escolha dois.)

a) Amazon Simple Queue Service (Amazon SQS)  
b) **Amazon CloudWatch**  
c) AWS Cost and Usage Report (Relatório de Custo e Uso da AWS)  
d) Cost Explorer (Explorador de Custos)  
e) **AWS Budgets**  

**Explicação:**
**Corretas:**
- **Amazon CloudWatch**:
  - Amazon CloudWatch pode ser configurado para monitorar métricas de custos usando CloudWatch Alarms. Esses alarmes podem ser configurados para enviar notificações quando certos limites de custo são atingidos, fornecendo uma camada adicional de monitoramento de gastos.
- **AWS Budgets**:
  - O AWS Budgets permite que você configure orçamentos personalizados para acompanhar os custos e o uso da AWS. Você pode definir alertas para ser notificado quando os custos ou uso atingirem valores predefinidos, ajudando a monitorar e controlar os gastos.

**Incorretas:**
- Amazon Simple Queue Service (Amazon SQS):
  - Amazon SQS é um serviço de fila que facilita a comunicação entre componentes distribuídos de uma aplicação, mas não é usado para monitoramento de custos ou notificações de orçamento.
- AWS Cost and Usage Report (Relatório de Custo e Uso da AWS):
  - O Relatório de Custo e Uso da AWS fornece informações detalhadas sobre os custos e o uso dos serviços da AWS, mas não envia notificações quando os limites de custo são atingidos.
- Cost Explorer (Explorador de Custos):
  - Cost Explorer é uma ferramenta que permite visualizar e analisar os custos da AWS ao longo do tempo, mas não possui recursos integrados de notificação de alertas de custo.

---

**Pergunta 10**

Uma empresa deseja armazenar dados no Amazon S3. A empresa raramente acessa os dados e os dados podem ser regenerados se necessário. A empresa deseja armazenar os dados na classe de armazenamento mais econômica.

Qual classe de armazenamento S3 atenderá a esse requisito?

a) S3 Standard-Infrequent Access (S3 Standard-IA)  
b) S3 Intelligent-Tiering  
c) **S3 One Zone-Infrequent Access (S3 One Zone-IA)**  
d) S3 Standard  

**Explicação:**
**Correta:**
- **S3 One Zone-Infrequent Access (S3 One Zone-IA)**:
  - Esta classe de armazenamento é projetada para dados que são acessados raramente, mas que podem ser regenerados facilmente se houver perda. S3 One Zone-IA armazena os dados em uma única zona de disponibilidade (AZ), o que a torna mais econômica em comparação com outras classes de armazenamento que replicam os dados em várias AZs. Portanto, esta é a opção mais econômica para a empresa, considerando que os dados podem ser regenerados se necessário.

**Incorretas:**
- S3 Standard-Infrequent Access (S3 Standard-IA):
  - Esta classe de armazenamento é projetada para dados que são acessados raramente, mas oferece alta durabilidade e replicação em várias AZs, o que a torna mais cara que a S3 One Zone-IA.
- S3 Intelligent-Tiering:
  - Esta classe move automaticamente os dados entre duas camadas (frequente e infrequente) com base no padrão de acesso. Embora seja econômica para dados com padrões de acesso imprevisíveis, ainda não é tão barata quanto a S3 One Zone-IA para dados raramente acessados que podem ser regenerados.
- S3 Standard:
  - Esta classe de armazenamento é projetada para dados que são frequentemente acessados. Embora ofereça alta durabilidade e disponibilidade, ela é mais cara em comparação com as classes de armazenamento infrequente.

---

**Pergunta 11**

Qual opção é uma localização física da infraestrutura global da AWS?

a) AWS Organizations  
b) **AWS Region**  
c) Amazon Connect  
d) AWS DataSync  

**Explicação:**
**Correta:**
- **AWS Region**:
  - AWS Region (Região da AWS) é uma localização física em uma área geográfica específica onde a AWS agrupa seus data centers. Cada região é composta por várias zonas de disponibilidade (Availability Zones), que são locais distintos e isolados dentro da região.

**Incorretas:**
- AWS Organizations:
  - AWS Organizations é um serviço que permite que você gerencie e controle múltiplas contas da AWS centralmente, mas não é uma localização física.
- Amazon Connect:
  - Amazon Connect é um serviço de central de contato baseado na nuvem que permite que as empresas configurem e gerenciem contact centers virtuais, mas também não é uma localização física.
- AWS DataSync:
  - AWS DataSync é um serviço de transferência de dados que automatiza a movimentação de dados entre armazenamento local e serviços de armazenamento da AWS, mas não é uma localização física.

---

**Pergunta 12**

Quais serviços ou ferramentas da AWS podem identificar oportunidades de redimensionamento para instâncias do Amazon EC2? (Escolha dois.)

a) Amazon CodeGuru  
b) AWS Billing Conductor  
c) **AWS Cost Explorer**  
d) Amazon SageMaker  
e) **AWS Compute Optimizer**  

**Explicação:**
**Corretas:**
- **AWS Cost Explorer**:
  - O AWS Cost Explorer fornece insights sobre os custos e o uso dos recursos da AWS, incluindo as instâncias do Amazon EC2. Ele pode ajudar a identificar padrões de uso e custos, o que pode indicar oportunidades de otimização e redimensionamento.
- **AWS Compute Optimizer**:
  - O AWS Compute Optimizer analisa o desempenho e o uso das instâncias do Amazon EC2, bem como dos grupos de Auto Scaling, e fornece recomendações de redimensionamento para otimizar a performance e reduzir os custos. Ele analisa o histórico de uso das instâncias e faz recomendações com base em métricas como CPU, memória, rede e armazenamento.

**Incorretas:**
- Amazon CodeGuru:
  - O Amazon CodeGuru é um serviço que fornece recomendações de otimização de código, identificando linhas de código que podem ser melhoradas em termos de desempenho e eficiência. No entanto, não está diretamente relacionado ao redimensionamento de instâncias do Amazon EC2.
- AWS Billing Conductor:
  - Não existe um serviço chamado "AWS Billing Conductor". Portanto, esta opção está incorreta.
- Amazon SageMaker:
  - O Amazon SageMaker é um serviço de aprendizado de máquina totalmente gerenciado que permite criar, treinar e implantar modelos de machine learning. Ele não está relacionado ao redimensionamento de instâncias do Amazon EC2 para otimização de desempenho e custo.

---

**Pergunta 13**

Uma empresa está configurando o AWS Identity and Access Management (IAM) em uma conta da AWS. Qual recomendação está em conformidade com as práticas recomendadas de segurança do IAM?

a) Usar as chaves de acesso do usuário root da conta para tarefas administrativas  
b) Conceder permissões amplas para que todos os funcionários da empresa possam acessar os recursos de que precisam  
c) Evitar a rotação de credenciais para prevenir problemas em aplicações de produção  
d) **Ativar a autenticação multifator (MFA) para maior segurança durante o processo de login**  

**Explicação:**
**Correta:**
- **Ativar a autenticação multifator (MFA) para maior segurança durante o processo de login**:
  - Ativar a autenticação multifator (MFA) é uma prática recomendada de segurança que adiciona uma camada extra de proteção ao processo de login, reduzindo o risco de acesso não autorizado, mesmo que as credenciais (usuário e senha) sejam comprometidas.

**Incorretas:**
- Usar as chaves de acesso do usuário root da conta para tarefas administrativas:
  - Usar as chaves de acesso do usuário root para tarefas administrativas é uma prática insegura. O usuário root deve ser usado apenas para tarefas iniciais de configuração e gerenciamento de contas, e suas chaves de acesso devem ser desativadas para evitar o uso indevido.
- Conceder permissões amplas para que todos os funcionários da empresa possam acessar os recursos de que precisam:
  - Conceder permissões amplas não segue o princípio de menor privilégio, que recomenda conceder aos usuários apenas as permissões mínimas necessárias para realizar suas tarefas, reduzindo o risco de acesso acidental ou malicioso a recursos críticos.
- Evitar a rotação de credenciais para prevenir problemas em aplicações de produção:
  - Evitar a rotação de credenciais é uma prática insegura. A rotação regular de credenciais ajuda a mitigar o risco de comprometimento e deve ser feita de forma planejada para minimizar impactos na produção.

---

**Pergunta 14**

Uma empresa está armazenando dados confidenciais de clientes em um bucket do Amazon S3. A empresa deseja proteger os dados contra exclusão ou substituição acidental. Qual recurso do S3 a empresa deve usar para atender a esses requisitos?

a) Criptografia no lado do servidor do S3 (S3 server-side encryption)  
b) Regras de ciclo de vida do S3 (S3 Lifecycle rules)  
c) **Versionamento do S3 (S3 Versioning)**  
d) Políticas de bucket do S3 (S3 bucket policies)  

**Explicação:**
**Correta:**
- **Versionamento do S3 (S3 Versioning)**:
  - Esta é a resposta correta porque o versionamento no S3 permite que você mantenha várias versões de um objeto em um bucket. Com o versionamento ativado, você pode proteger seus dados contra exclusão acidental, pois todas as versões anteriores de um objeto são preservadas. Isso significa que, se um objeto for excluído ou substituído, a versão anterior ainda estará disponível para recuperação.

**Incorretas:**
- Criptografia no lado do servidor do S3 (S3 server-side encryption):
  - Esta opção está incorreta porque a criptografia no lado do servidor do S3 protege os dados em repouso criptografando os objetos, mas não impede a exclusão ou substituição acidental dos objetos.
- Regras de ciclo de vida do S3 (S3 Lifecycle rules):
  - Esta opção está incorreta porque as regras de ciclo de vida do S3 são usadas para gerenciar o ciclo de vida dos objetos no bucket, como transição para classes de armazenamento mais baratas ou expiração de objetos, mas não protegem diretamente contra exclusão ou substituição acidental.
- Políticas de bucket do S3 (S3 bucket policies):
  - Esta opção está incorreta porque as políticas de bucket controlam o acesso aos recursos do bucket, especificando quem pode realizar quais ações, mas não fornecem proteção específica contra exclusão ou substituição acidental de objetos.

---

**Pergunta 15**

Uma empresa deseja monitorar o desempenho de sua carga de trabalho. A empresa quer garantir que os serviços em nuvem sejam entregues em um nível que atenda às suas necessidades de negócios.

Qual perspectiva do AWS Cloud Adoption Framework (AWS CAF) atenderá a esses requisitos?

a) Plataforma  
b) Negócios  
c) Governança  
d) **Operações**  

**Explicação:**
**Correta:**
- **Operações**:
  - A perspectiva de Operações do AWS Cloud Adoption Framework (AWS CAF) foca em gerenciar e monitorar os serviços em nuvem para garantir que eles sejam entregues de maneira eficaz e eficiente, atendendo às necessidades de negócios da empresa. Essa perspectiva inclui atividades como monitoramento do desempenho das cargas de trabalho, manutenção da saúde e desempenho dos sistemas, e resposta a eventos operacionais para garantir a continuidade dos negócios e a satisfação das necessidades dos clientes.

**Incorretas:**
- Plataforma:
  - A perspectiva de Plataforma se concentra na infraestrutura de TI e na arquitetura técnica necessária para suportar as cargas de trabalho na nuvem. Embora seja importante para a entrega dos serviços, não é especificamente responsável pelo monitoramento contínuo do desempenho das cargas de trabalho.
- Negócios:
  - A perspectiva de Negócios foca na criação de um caso de negócio, planejamento de mudanças organizacionais e alinhamento da estratégia de TI com os objetivos de negócios da empresa. Ela não é diretamente responsável pelo monitoramento do desempenho das cargas de trabalho.
- Governança:
  - A perspectiva de Governança se concentra em alinhar a governança de TI com a governança empresarial, garantindo que a TI cumpra as políticas, regulamentações e padrões da empresa. Não está diretamente focada no monitoramento do desempenho operacional das cargas de trabalho.

---

**Pergunta 16**

Qual serviço da AWS oferece a capacidade de gerenciar infraestrutura como código?

a) AWS CodePipeline  
b) AWS CodeDeploy  
c) AWS Direct Connect  
d) **AWS CloudFormation**  

**Explicação:**
**Correta:**
- **AWS CloudFormation**:
  - AWS CloudFormation oferece a capacidade de gerenciar infraestrutura como código. Ele permite que os usuários definam e provisionem a infraestrutura da AWS de maneira previsível e ordenada usando arquivos de configuração (templates), que podem ser versionados e compartilhados.

**Incorretas:**
- AWS CodePipeline:
  - AWS CodePipeline é um serviço de integração e entrega contínua que ajuda a automatizar os pipelines de release para aplicações. Não gerencia infraestrutura como código; em vez disso, orquestra o processo de build, test e deploy de software.
- AWS CodeDeploy:
  - AWS CodeDeploy é um serviço de implantação que automatiza a implementação de software em diversos serviços de computação, como Amazon EC2, AWS Lambda e instâncias locais. Ele gerencia o processo de deploy, mas não a infraestrutura como código.
- AWS Direct Connect:
  - AWS Direct Connect é um serviço de rede que permite estabelecer uma conexão de rede dedicada entre o seu datacenter e a AWS. Ele melhora a performance de rede, mas não tem relação com o gerenciamento de infraestrutura como código.

---

**Pergunta 17**

Uma empresa está executando e gerenciando seu próprio ambiente Docker em instâncias do Amazon EC2. A empresa deseja uma alternativa para ajudar a gerenciar o tamanho do cluster, a programação e a manutenção do ambiente. Qual serviço da AWS atende a esses requisitos?

a) Amazon RDS  
b) **AWS Fargate**  
c) Amazon Athena  
d) AWS Lambda  

**Explicação:**
**Correta:**
- **AWS Fargate**:
  - O AWS Fargate é um serviço da AWS que permite executar contêineres sem a necessidade de gerenciar a infraestrutura subjacente. Com o Fargate, você simplesmente define seus contêineres e deixa a AWS lidar com a provisionamento de recursos, escalonamento e gerenciamento do ambiente de contêineres. Isso inclui o gerenciamento do tamanho do cluster, a programação dos contêineres e a manutenção do ambiente, o que se alinha diretamente com os requisitos da empresa descritos na pergunta.

**Incorretas:**
- Amazon RDS:
  - O Amazon RDS é um serviço de banco de dados relacional gerenciado. Não está relacionado diretamente ao gerenciamento de contêineres Docker ou à execução de aplicativos em contêineres.
- Amazon Athena:
  - O Amazon Athena é um serviço de análise interativo da AWS que permite analisar dados diretamente no Amazon S3 usando SQL padrão. Ele não está relacionado ao gerenciamento de contêineres Docker ou à execução de aplicativos em contêineres.
- AWS Lambda:
  - O AWS Lambda é um serviço de computação sem servidor que executa código em resposta a eventos. Embora possa ser usado para processamento de dados e outras tarefas, não é uma solução direta para gerenciar contêineres Docker como solicitado na pergunta.

---

**Pergunta 18**

Uma plataforma de e-learning precisa executar um aplicativo durante 2 meses por ano. O aplicativo será implantado em instâncias do Amazon EC2. Qualquer tempo de inatividade do aplicativo durante esses 2 meses deve ser evitado. Qual opção de compra do EC2 atenderá a esses requisitos de maneira MAIS econômica?

a) Spot Instances (Instâncias Spot)  
b) **On-Demand Instances (Instâncias Sob Demanda)**  
c) Reserved Instances (Instâncias Reservadas)  
d) Dedicated Hosts (Hosts Dedicados)  

**Explicação:**
**Correta:**
- **On-Demand Instances (Instâncias Sob Demanda)**:
  - Esta é a resposta correta porque as Instâncias Sob Demanda permitem que você pague pela capacidade de computação por hora ou por segundo, sem compromisso de longo prazo. Para um uso de 2 meses por ano, esta é a opção mais econômica e flexível, garantindo que o aplicativo esteja sempre disponível durante o período necessário, evitando qualquer tempo de inatividade.

**Incorretas:**
- Spot Instances (Instâncias Spot):
  - Esta opção está incorreta porque as Instâncias Spot são oferecidas a preços significativamente mais baixos, mas podem ser interrompidas pela AWS com um aviso de apenas dois minutos se a capacidade for necessária para outra demanda. Isso não atende ao requisito de evitar qualquer tempo de inatividade.
- Reserved Instances (Instâncias Reservadas):
  - Esta opção está incorreta porque as Instâncias Reservadas são mais econômicas para uso contínuo ou previsível ao longo de um ano ou mais, com compromissos de 1 ou 3 anos. Para um uso de apenas 2 meses por ano, isso não seria a opção mais econômica.
- Dedicated Hosts (Hosts Dedicados):
  - Esta opção está incorreta porque os Hosts Dedicados são mais caros e são usados principalmente quando você precisa de um servidor físico dedicado para atender a requisitos específicos de conformidade ou licenciamento. Para um uso de 2 meses por ano, essa seria uma opção desnecessariamente cara.

---

**Pergunta 19**

Qual serviço ou recurso da AWS é usado para enviar mensagens de texto e e-mail de aplicativos distribuídos?

a) Amazon Simple Queue Service (Amazon SQS)  
b) Amazon Simple Email Service (Amazon SES)  
c) **Amazon Simple Notification Service (Amazon SNS)**  
d) Amazon CloudWatch alerts (Alertas do Amazon CloudWatch)  

**Explicação:**
**Correta:**
- **Amazon Simple Notification Service (Amazon SNS)**:
  - Amazon Simple Notification Service (Amazon SNS) é um serviço de mensagens que permite enviar notificações em forma de mensagens de texto (SMS) e e-mails a partir de aplicativos distribuídos. O SNS suporta a entrega de mensagens a um grande número de assinantes ou endpoints, facilitando a comunicação em sistemas distribuídos.

**Incorretas:**
- Amazon Simple Queue Service (Amazon SQS):
  - O Amazon SQS é um serviço de fila que facilita a comunicação entre componentes de um sistema distribuído, mas não envia notificações diretamente por e-mail ou mensagens de texto.
- Amazon Simple Email Service (Amazon SES):
  - O Amazon SES é um serviço de e-mail que permite enviar e-mails em massa de forma econômica, mas não envia mensagens de texto (SMS).
- Amazon CloudWatch alerts (Alertas do Amazon CloudWatch):
  - O Amazon CloudWatch é um serviço de monitoramento que pode enviar alertas baseados em métricas e logs, mas não é especificamente usado para enviar mensagens de texto ou e-mails a partir de aplicativos distribuídos.

---

**Pergunta 20**

Uma empresa precisa de armazenamento de arquivos totalmente gerenciado, altamente confiável e escalável, acessível por meio do protocolo Server Message Block (SMB). Qual serviço da AWS atenderá a esses requisitos?

a) Amazon Elastic File System (Amazon EFS)  
b) Amazon S3  
c) **Amazon FSx para servidor de arquivos Windows**  
d) Amazon Elastic Block Store (Amazon EBS)  

**Explicação:**
**Correta:**
- **Amazon FSx para servidor de arquivos Windows**:
  - O Amazon FSx for Windows File Server oferece um sistema de arquivos totalmente gerenciado que é acessível por meio do protocolo SMB. Ele é altamente confiável, escalável e adequado para aplicativos e cargas de trabalho que precisam de armazenamento de arquivos com suporte ao SMB.

**Incorretas:**
- Amazon Elastic File System (Amazon EFS):
  - O Amazon EFS é um sistema de arquivos NFS (Network File System) escalável para uso com instâncias do Amazon EC2, mas não suporta o protocolo SMB.
- Amazon S3:
  - O Amazon S3 é um serviço de armazenamento de objetos e não oferece suporte nativo para o protocolo SMB.
- Amazon Elastic Block Store (Amazon EBS):
  - O Amazon EBS fornece volumes de armazenamento em bloco para uso com instâncias do Amazon EC2. Ele não é um serviço de armazenamento de arquivos e não suporta diretamente o protocolo SMB.

---

**Pergunta 21**

Uma empresa executa milhares de simulações simultâneas usando o AWS Batch. Cada simulação não tem estado, é tolerante a falhas e dura até 3 horas. Qual modelo de precificação permite à empresa otimizar custos e atender a esses requisitos?

a) Dedicated Instances (Instâncias Dedicadas)  
b) **Spot Instances (Instâncias Spot)**  
c) Reserved Instances (Instâncias Reservadas)  
d) On-Demand Instances (Instâncias Sob Demanda)  

**Explicação:**
**Correta:**
- **Spot Instances (Instâncias Spot)**:
  - As Spot Instances (Instâncias Spot) permitem que você aproveite a capacidade ociosa da AWS a preços reduzidos, oferecendo um custo muito menor em comparação com as Instâncias Sob Demanda. Dado que as simulações são tolerantes a falhas e não têm estado, elas podem ser interrompidas e reiniciadas sem impacto significativo, tornando as Instâncias Spot uma escolha ideal para otimizar custos.

**Incorretas:**
- Dedicated Instances (Instâncias Dedicadas):
  - As Instâncias Dedicadas são executadas em hardware dedicado a um único cliente, o que oferece isolamento físico, mas é a opção mais cara e não necessária para simulações tolerantes a falhas e sem estado.
- Reserved Instances (Instâncias Reservadas):
  - Embora as Instâncias Reservadas ofereçam um desconto em relação às Instâncias Sob Demanda em troca de um compromisso de longo prazo, elas não são tão econômicas quanto as Instâncias Spot para cargas de trabalho que podem tolerar interrupções.
- On-Demand Instances (Instâncias Sob Demanda):
  - As Instâncias Sob Demanda oferecem flexibilidade sem compromissos de longo prazo, mas são mais caras em comparação com as Instâncias Spot, não sendo a melhor opção para otimização de custos em cargas de trabalho tolerantes a falhas.

---

**Pergunta 22**

Quais tarefas são responsabilidades do cliente, de acordo com o modelo de responsabilidade compartilhada da AWS? (Escolha dois.)

a) **Classify company assets in the AWS Cloud (Classificar ativos da empresa na Nuvem AWS)**  
b) Determine which Availability Zones to use for Amazon S3 buckets (Determinar quais Zonas de Disponibilidade usar para buckets do Amazon S3)  
c) Patch or upgrade Amazon DynamoDB (Atualizar ou fazer upgrade do Amazon DynamoDB)  
d) Select Amazon EC2 instances to run AWS Lambda on (Selecionar instâncias do Amazon EC2 para executar o AWS Lambda)  
e) **Configure the AWS provided security group firewall (Configurar o firewall do grupo de segurança fornecido pela AWS)**  

**Explicação:**
**Corretas:**
- **Classify company assets in the AWS Cloud (Classificar ativos da empresa na Nuvem AWS)**:
  - A classificação dos ativos da empresa, incluindo dados sensíveis e outros recursos críticos, é de responsabilidade do cliente. O cliente deve definir a sensibilidade dos dados e implementar as medidas de segurança apropriadas.
- **Configure the AWS provided security group firewall (Configurar o firewall do grupo de segurança fornecido pela AWS)**:
  - No modelo de responsabilidade compartilhada, a AWS é responsável pela segurança da nuvem, enquanto o cliente é responsável pela segurança na nuvem. Isso inclui a configuração de regras de firewall dos grupos de segurança para controlar o tráfego de rede para suas instâncias.

**Incorretas:**
- Determine which Availability Zones to use for Amazon S3 buckets (Determinar quais Zonas de Disponibilidade usar para buckets do Amazon S3):
  - O Amazon S3 é um serviço de armazenamento gerenciado que não requer a seleção de Zonas de Disponibilidade específicas pelo cliente.
- Patch or upgrade Amazon DynamoDB (Atualizar ou fazer upgrade do Amazon DynamoDB):
  - A AWS é responsável pela manutenção, incluindo patching e upgrades, dos serviços gerenciados como o Amazon DynamoDB.
- Select Amazon EC2 instances to run AWS Lambda on (Selecionar instâncias do Amazon EC2 para executar o AWS Lambda):
  - O AWS Lambda é um serviço gerenciado que não requer a seleção de instâncias do Amazon EC2 pelo cliente. A AWS gerencia a infraestrutura subjacente para o Lambda.

---

**Pergunta 23**

Uma empresa precisa contratar consultoresfnter e dar suporte ao seu ambiente AWS e às necessidades de negócios da empresa. Qual serviço ou recurso da AWS atenderá a esses requisitos?

a) Organizações AWS  
b) **Rede de parceiros da AWS (APN)**  
c) Suporte da AWS  
d) Catálogo de serviços AWS  

**Explicação:**
**Correta:**
- **Rede de parceiros da AWS (APN)**:
  - A AWS Partner Network (APN) é um programa global de parceiros que oferece suporte a consultores, provedores de serviços, integradores de sistemas, e fornecedores independentes de software (ISVs) para construir soluções e serviços na AWS. Através da APN, as empresas podem encontrar consultores terceirizados qualificados que podem fornecer suporte e manutenção para o ambiente AWS e atender às necessidades de negócios.

**Incorretas:**
- Organizações AWS:
  - O AWS Organizations é um serviço que permite gerenciar e consolidar várias contas da AWS dentro de uma organização, mas não é usado para contratar consultores terceirizados.
- Suporte da AWS:
  - O suporte da AWS oferece assistência técnica e orientação em relação ao uso dos serviços da AWS, mas não fornece consultores terceirizados.
- Catálogo de serviços AWS:
  - O AWS Service Catalog permite que organizações criem e gerenciem catálogos de serviços de TI aprovados para uso na AWS, mas não é destinado a contratar consultores terceirizados.

---

**Pergunta 24**

O que significa o conceito de agilidade na computação em nuvem AWS? (Escolha dois.)

a) **The speed at which AWS resources are implemented (A velocidade com que os recursos da AWS são implementados)**  
b) The low cost of entry into cloud computing (O baixo custo de entrada na computação em nuvem)  
c) **The ability to experiment quickly (A capacidade de experimentar rapidamente)**  
d) The elimination of wasted capacity (A eliminação da capacidade desperdiçada)  
e) The speed at which AWS creates new AWS Regions (A velocidade com que a AWS cria novas Regiões da AWS)  

**Explicação:**
**Corretas:**
- **The speed at which AWS resources are implemented (A velocidade com que os recursos da AWS são implementados)**:
  - A agilidade na computação em nuvem AWS inclui a capacidade de provisionar rapidamente novos recursos conforme necessário. Isso permite que as empresas respondam rapidamente às mudanças nas demandas do mercado e nas necessidades dos negócios.
- **The ability to experiment quickly (A capacidade de experimentar rapidamente)**:
  - A agilidade também se refere à capacidade de experimentar novas ideias e testar hipóteses rapidamente, com baixo custo e risco. Isso é facilitado pela elasticidade e escalabilidade dos serviços AWS, permitindo que as empresas inovem mais rapidamente.

**Incorretas:**
- The low cost of entry into cloud computing (O baixo custo de entrada na computação em nuvem):
  - Embora o baixo custo de entrada seja um benefício da computação em nuvem, não é especificamente um aspecto do conceito de agilidade.
- The elimination of wasted capacity (A eliminação da capacidade desperdiçada):
  - A eliminação da capacidade desperdiçada está mais relacionada à eficiência de custos e à otimização de recursos do que à agilidade.
- The speed at which AWS creates new AWS Regions (A velocidade com que a AWS cria novas Regiões da AWS):
  - Embora a criação de novas regiões AWS possa impactar a disponibilidade de recursos em diferentes locais geográficos, não está diretamente relacionada ao conceito de agilidade em termos de uso e experimentação de recursos de computação em nuvem.

---

**Pergunta 25**

Quais ações são de responsabilidade da AWS, de acordo com o modelo de responsabilidade compartilhada da AWS? (Escolha dois.)

a) Aplicação de patches no sistema operacional em instâncias do Amazon EC2  
b) Aplicação de uma política de senha rígida para usuários do IAM  
c) Configurando grupos de segurança e ACLs de rede  
d) **Aplicação de patches no sistema operacional em instâncias do Amazon RDS**  
e) **Protegendo a camada de virtualização**  

**Explicação:**
**Corretas:**
- **Aplicação de patches no sistema operacional em instâncias do Amazon RDS**:
  - A AWS gerencia o sistema operacional subjacente e aplica patches e atualizações de segurança nas instâncias do Amazon RDS. Isso faz parte do compromisso da AWS com a segurança e a manutenção da infraestrutura.
- **Protegendo a camada de virtualização**:
  - A AWS é responsável pela segurança da infraestrutura que executa todos os serviços oferecidos na Nuvem AWS. Isso inclui a proteção da camada de virtualização, que é parte da infraestrutura subjacente que hospeda instâncias do EC2 e outros recursos.

**Incorretas:**
- Aplicação de patches no sistema operacional em instâncias do Amazon EC2:
  - Os clientes são responsáveis pela manutenção do sistema operacional e pela aplicação de patches nas instâncias do Amazon EC2.
- Aplicação de uma política de senha rígida para usuários do IAM:
  - Os clientes são responsáveis pela configuração de políticas de senha e pelo gerenciamento de usuários do IAM.
- Configurando grupos de segurança e ACLs de rede:
  - Os clientes são responsáveis pela configuração de grupos de segurança e listas de controle de acesso (ACLs) de rede para controlar o tráfego de entrada e saída de suas instâncias.

---

**Pergunta 26**

Qual opção é uma perspectiva que inclui recursos básicos do AWS Cloud Adoption Framework (AWS CAF)?

a) Sustentabilidade  
b) **Governança**  
c) Eficiência de desempenho  
d) Confiabilidade  

**Explicação:**
**Correta:**
- **Governança**:
  - No contexto do AWS Cloud Adoption Framework (AWS CAF), a governança é uma perspectiva fundamental que inclui recursos básicos. O AWS CAF fornece orientações sobre como estabelecer e manter a governança na nuvem da AWS, garantindo que os recursos de TI sejam utilizados de forma eficiente e segura, alinhados com os objetivos e políticas organizacionais.

**Incorretas:**
- Sustentabilidade:
  - Embora a sustentabilidade seja um conceito importante, não é uma perspectiva fundamental do AWS Cloud Adoption Framework (AWS CAF). O AWS CAF se concentra principalmente em aspectos relacionados à adoção e operação eficaz da nuvem da AWS, e a sustentabilidade pode não estar diretamente ligada a esses objetivos.
- Eficiência de desempenho:
  - A eficiência de desempenho é importante na operação de sistemas na nuvem, mas não é uma perspectiva fundamental do AWS Cloud Adoption Framework (AWS CAF). Enquanto o AWS CAF aborda aspectos como governança, operação eficiente e segurança na nuvem, a eficiência de desempenho pode ser considerada como uma consideração secundária dentro desses tópicos.
- Confiabilidade:
  - Embora a confiabilidade seja crucial na operação de sistemas na nuvem, não é uma perspectiva fundamental do AWS Cloud Adoption Framework (AWS CAF). O AWS CAF enfoca principalmente aspectos relacionados à governança, operação eficiente e segurança na nuvem, e embora a confiabilidade seja um componente importante, não é a perspectiva principal abordada pelo AWS CAF.

---

**Pergunta 27**

Um profissional de nuvem precisa obter relatórios de conformidade da AWS antes de migrar um ambiente para a nuvem AWS. Como esses relatórios podem ser gerados?

a) Contactar a equipe de Conformidade da AWS  
b) **Baixar os relatórios do AWS Artifact**  
c) Abrir um caso com o Suporte da AWS  
d) Gerar os relatórios com Amazon Macie  

**Explicação:**
**Correta:**
- **Baixar os relatórios do AWS Artifact**:
  - O AWS Artifact é um portal self-service que fornece acesso a relatórios de conformidade e outros documentos da AWS. Os clientes podem usar o AWS Artifact para baixar relatórios de conformidade e outros documentos que demonstram a conformidade da AWS com padrões de segurança e regulamentações, ajudando a facilitar a migração para a nuvem AWS.

**Incorretas:**
- Contactar a equipe de Conformidade da AWS:
  - Embora a equipe de Conformidade da AWS possa fornecer orientação e suporte, os relatórios de conformidade são prontamente acessíveis através do AWS Artifact, tornando desnecessário o contato direto com a equipe de conformidade.
- Abrir um caso com o Suporte da AWS:
  - Abrir um caso com o Suporte da AWS pode não ser a forma mais eficiente de obter relatórios de conformidade, pois esses relatórios são facilmente acessíveis através do AWS Artifact.
- Gerar os relatórios com Amazon Macie:
  - O Amazon Macie é um serviço de segurança e conformidade que usa machine learning para identificar e proteger dados confidenciais armazenados no Amazon S3, mas não é usado para gerar relatórios de conformidade da AWS.

---

**Pergunta 28**

Qual opção é de responsabilidade do cliente ao usar o Amazon DynamoDB no modelo de responsabilidade compartilhada da AWS?

a) O acesso às tabelas do DynamoDB  
b) A aplicação de patches no DynamoDB  
c) **A criptografia dos dados em repouso no DynamoDB**  
d) A segurança física do DynamoDB  

**Explicação:**
**Correta:**
- **A criptografia dos dados em repouso no DynamoDB**:
  - No modelo de responsabilidade compartilhada da AWS, é responsabilidade do cliente garantir que os dados armazenados no Amazon DynamoDB sejam criptografados adequadamente enquanto estão em repouso. Isso significa que o cliente precisa implementar e gerenciar a criptografia dos dados para protegê-los contra acessos não autorizados.

**Incorretas:**
- O acesso às tabelas do DynamoDB:
  - O acesso às tabelas do DynamoDB é controlado através das políticas de controle de acesso IAM (Identity and Access Management) da AWS. A gestão dessas políticas é compartilhada entre a AWS e o cliente. O cliente precisa configurar e gerenciar as permissões de acesso, enquanto a AWS garante a infraestrutura e os mecanismos para aplicar essas políticas.
- A aplicação de patches no DynamoDB:
  - A aplicação de patches no DynamoDB é gerenciada pela AWS. Como parte de sua responsabilidade, a AWS garante que o serviço esteja atualizado e protegido contra vulnerabilidades conhecidas.
- A segurança física do DynamoDB:
  - A segurança física do DynamoDB é responsabilidade da AWS, não do cliente. Isso inclui a proteção dos data centers onde o DynamoDB é hospedado.

---

**Pergunta 29**

Qual serviço ou recurso da AWS pode ser usado para identificar serviços que foram usados ​​por um usuário em um intervalo de datas especificado?

a) Analisador de acesso à rede  
b) AWS Certificate Manager (ACM)  
c) **Analisador de acesso do AWS Identity and Access Management**  
d) Listas de controle de acesso (ACLs) do Amazon S3  

**Explicação:**
**Correta:**
- **Analisador de acesso do AWS Identity and Access Management**:
  - O AWS IAM Access Analyzer é uma ferramenta que ajuda a analisar e identificar os serviços e recursos acessados por usuários e roles no AWS IAM. Ele permite que os administradores de segurança visualizem e monitorem as permissões e acessos de seus usuários e identifiquem possíveis problemas de segurança, facilitando a auditoria e o controle dos acessos em um intervalo de datas especificado.

**Incorretas:**
- Analisador de acesso à rede:
  - O Network Access Analyzer é usado para analisar a conectividade e as permissões de rede, mas não é usado para rastrear serviços usados por usuários específicos em um intervalo de datas.
- AWS Certificate Manager (ACM):
  - O ACM é um serviço para gerenciar certificados SSL/TLS, mas não é usado para identificar serviços utilizados por usuários.
- Listas de controle de acesso (ACLs) do Amazon S3:
  - As ACLs do Amazon S3 são usadas para controlar o acesso a buckets e objetos no S3, mas não fornecem informações sobre os serviços usados por um usuário.

---

**Pergunta 30**

Qual tarefa é de responsabilidade da AWS, de acordo com o modelo de responsabilidade compartilhada da AWS?

a) Gerenciar opções de criptografia para dados armazenados na AWS  
b) Configurar grupos de segurança para instâncias do Amazon EC2  
c) Configurar o gerenciamento de identidade e acesso para aplicativos  
d) **Manter o hardware físico da infraestrutura**  

**Explicação:**
**Correta:**
- **Manter o hardware físico da infraestrutura**:
  - De acordo com o modelo de responsabilidade compartilhada da AWS, a AWS é responsável pela "segurança da nuvem". Isso inclui a manutenção do hardware físico, a infraestrutura de rede e os data centers onde os serviços da AWS operam.

**Incorretas:**
- Gerenciar opções de criptografia para dados armazenados na AWS:
  - Embora a AWS forneça ferramentas e serviços de criptografia, é responsabilidade do cliente gerenciar e aplicar as políticas de criptografia para seus dados.
- Configurar grupos de segurança para instâncias do Amazon EC2:
  - A configuração de grupos de segurança é de responsabilidade do cliente, que deve definir as regras de firewall que controlam o tráfego de entrada e saída para suas instâncias EC2.
- Configurar o gerenciamento de identidade e acesso para aplicativos:
  - Esta é uma responsabilidade do cliente, pois envolve a configuração de usuários, grupos e permissões específicos para controlar o acesso aos recursos da AWS.

---

**Pergunta 31**

Uma empresa possui uma biblioteca de fitas física para armazenar backups de dados. A biblioteca de fitas está ficando sem espaço. A empresa precisa estender a capacidade da biblioteca de fitas para a Nuvem AWS. Qual serviço da AWS a empresa deve usar para atender a esse requisito?

a) Amazon Elastic Block Store (Amazon EBS)  
b) **AWS Storage Gateway**  
c) Amazon S3  
d) Amazon Elastic File System (Amazon EFS)  

**Explicação:**
**Correta:**
- **AWS Storage Gateway**:
  - O AWS Storage Gateway é um serviço que conecta um ambiente local ao armazenamento em nuvem da AWS, oferecendo uma solução de armazenamento híbrido. Ele oferece uma biblioteca de fitas virtual (VTL) que permite que os dados de backup sejam armazenados de forma eficiente na AWS, estendendo a capacidade de armazenamento de fitas físicas sem a necessidade de investimento adicional em hardware.

**Incorretas:**
- Amazon Elastic Block Store (Amazon EBS):
  - O Amazon EBS fornece armazenamento em bloco para instâncias do Amazon EC2, mas não é uma solução para substituir ou estender bibliotecas de fitas.
- Amazon S3:
  - O Amazon S3 é um serviço de armazenamento de objetos altamente escalável e durável, mas não oferece integração direta com bibliotecas de fitas físicas, diferentemente do AWS Storage Gateway.
- Amazon Elastic File System (Amazon EFS):
  - O Amazon EFS é um sistema de arquivos para armazenamento compartilhado que pode ser montado em instâncias do Amazon EC2, mas não é projetado especificamente para estender bibliotecas de fitas.

---

**Pergunta 32**

Uma empresa deseja configurar suas cargas de trabalho para realizar suas funções pretendidas e se recuperar rapidamente de falhas. Qual pilar do AWS Well-Architected Framework alinha-se com esses objetivos?

a) Eficiência de desempenho  
b) Segurança  
c) **Confiabilidade**  
d) Sustentabilidade  

**Explicação:**
**Correta:**
- **Confiabilidade**:
  - O pilar de Confiabilidade do AWS Well-Architected Framework se concentra em garantir que uma carga de trabalho execute suas funções pretendidas corretamente e possa se recuperar rapidamente de falhas para atender às demandas de negócios. Este pilar inclui práticas recomendadas para a recuperação de desastres, backup e restauração, e design de sistemas resilientes que podem se adaptar a mudanças em carga e falhas de infraestrutura.

**Incorretas:**
- Eficiência de desempenho:
  - O pilar de Eficiência de Desempenho se concentra em usar recursos de TI de maneira eficiente para atender aos requisitos de sistema e desempenho, mas não aborda diretamente a recuperação rápida de falhas.
- Segurança:
  - O pilar de Segurança trata da proteção de informações e sistemas, incluindo práticas recomendadas para controle de acesso, proteção de dados e conformidade com regulamentos. Embora importante, ele não é especificamente focado na recuperação rápida de falhas.
- Sustentabilidade:
  - O pilar de Sustentabilidade é o mais novo pilar do AWS Well-Architected Framework e se concentra em minimizar o impacto ambiental e aumentar a eficiência dos recursos de TI. Este pilar não está diretamente relacionado à recuperação de falhas.

---

**Pergunta 33**

Uma empresa implantou aplicativos em instâncias do Amazon EC2. A empresa precisa avaliar as vulnerabilidades das aplicações e identificar implantações de infraestrutura que não atendam às melhores práticas. Qual serviço AWS a empresa pode usar para atender a esses requisitos?

a) AWS Config  
b) AWS Trusted Advisor  
c) Amazon GuardDuty  
d) **Amazon Inspector**  

**Explicação:**
**Correta:**
- **Amazon Inspector**:
  - O Amazon Inspector foi projetado especificamente para avaliar vulnerabilidades de aplicações hospedadas em instâncias do EC2 e para identificar implantações de infraestrutura que não atendem às melhores práticas.

**Incorretas:**
- AWS Config:
  - O AWS Config é um serviço que permite avaliar, auditar e avaliar as configurações dos recursos da AWS. Ele monitora e registra continuamente as configurações de seus recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas. No entanto, ele não é usado para avaliar vulnerabilidades de aplicações diretamente.
- AWS Trusted Advisor:
  - O AWS Trusted Advisor oferece recomendações para otimização de recursos, economia de custos, desempenho, tolerância a falhas e melhorias de segurança. Embora útil, ele não é específico para a avaliação de vulnerabilidades de aplicações em instâncias do EC2.
- Amazon GuardDuty:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento anômalo para proteger suas contas da AWS, cargas de trabalho e dados armazenados no Amazon S3. Ele se concentra na detecção de ameaças e não especificamente na avaliação de vulnerabilidades de aplicações.

---

**Pergunta 34**

Uma empresa precisa planejar, agendar e executar centenas de milhares de trabalhos de computação na AWS. Qual serviço AWS a empresa pode usar para atender a esse requisito?

a) Amazon Simple Queue Service (Amazon SQS)  
b) Catálogo de serviços AWS  
c) Funções de etapas da AWS  
d) **Lote AWS**  

**Explicação:**
**Correta:**
- **Lote AWS**:
  - O AWS Batch é um serviço gerenciado que permite que desenvolvedores, cientistas e engenheiros executem facilmente centenas de milhares de jobs de computação em lote de qualquer escala, usando a capacidade do Amazon EC2. Ele gerencia de forma eficiente e dinâmica a alocação de recursos de computação e otimiza a distribuição de jobs dentro de um ou mais ambientes de execução especificados pelo usuário.

**Incorretas:**
- Amazon Simple Queue Service (Amazon SQS):
  - Amazon SQS é um serviço de fila de mensagens que permite desacoplar e escalar microsserviços, sistemas distribuídos e aplicativos sem servidor. Embora possa ser usado em conjunto com outros serviços para orquestrar jobs, não fornece uma solução completa e direta para agendamento e execução de trabalhos de computação em larga escala como o AWS Batch.
- Catálogo de serviços AWS:
  - AWS Service Catalog é usado para criar e gerenciar catálogos de serviços de TI aprovados para uso em AWS, mas não é adequado para agendar e executar trabalhos de computação em larga escala.
- Funções de etapas da AWS:
  - AWS Step Functions é um orquestrador de serviços que permite coordenar múltiplos serviços AWS em fluxos de trabalho serverless. Não é específico para agendar e executar grandes volumes de jobs de computação.

---

**Pergunta 35**

Uma empresa muitas vezes não utiliza toda a sua capacidade atual do Amazon EC2 para executar cargas de trabalho sem estado. A empresa deseja otimizar seus custos com EC2. Qual tipo de instância EC2 atenderá a esses requisitos?

a) Instâncias Sob Demanda  
b) Instâncias Dedicadas  
c) Instâncias Reservadas  
d) **Instâncias Spot**  

**Explicação:**
**Correta:**
- **Instâncias Spot**:
  - As Instâncias Spot da AWS permitem que você aproveite a capacidade de computação não utilizada na AWS com descontos significativos. Essas instâncias são ideais para cargas de trabalho sem estado que podem ser interrompidas a qualquer momento, o que é exatamente o cenário descrito na questão. Portanto, ao utilizar Instâncias Spot, a empresa pode otimizar significativamente seus custos com EC2.

**Incorretas:**
- Instâncias Sob Demanda:
  - As Instâncias Sob Demanda permitem pagar pela capacidade de computação por hora sem compromisso a longo prazo. Elas são mais caras em comparação com as Instâncias Spot e não são a melhor opção para otimização de custos quando há capacidade não utilizada.
- Instâncias Dedicadas:
  - As Instâncias Dedicadas são executadas em um hardware físico dedicado a um único cliente. Elas são mais caras e não são a melhor opção para otimização de custos em cargas de trabalho que não precisam de isolamento físico.
- Instâncias Reservadas:
  - As Instâncias Reservadas oferecem descontos em troca de um compromisso de uso por um ou três anos. Embora possam economizar custos para cargas de trabalho previsíveis e de longo prazo, elas não são tão eficazes quanto as Instâncias Spot para cargas de trabalho esporádicas e sem estado que não utilizam toda a capacidade.

---

**Pergunta 36**

Uma empresa precisa configurar e gerenciar centralmente grupos de segurança da Amazon VPC em várias contas da AWS em uma organização no AWS Organizations. Qual serviço AWS a empresa deve usar para atender a esses requisitos?

a) Detetive da Amazon  
b) **AWS Firewall Manager**  
c) Amazon GuardDuty  
d) AWS WAF  

**Explicação:**
**Correta:**
- **AWS Firewall Manager**:
  - O AWS Firewall Manager é um serviço de gerenciamento de segurança que permite configurar e gerenciar centralmente regras de firewall em várias contas e recursos da AWS. Ele é ideal para gerenciar grupos de segurança da VPC em uma organização que utiliza AWS Organizations.

**Incorretas:**
- Detetive da Amazon:
  - O Amazon Detective ajuda a analisar e investigar possíveis problemas de segurança ou atividades suspeitas. Ele não é usado para configurar e gerenciar grupos de segurança.
- Amazon GuardDuty:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento não autorizado para proteger suas contas e cargas de trabalho da AWS. Ele não é usado para gerenciar grupos de segurança.
- AWS WAF:
  - O AWS WAF é um firewall de aplicação web que ajuda a proteger suas aplicações web contra exploits da web comuns. Ele não é usado para gerenciar grupos de segurança da VPC.

---

**Pergunta 37**

Qual serviço ou recurso da AWS identifica se um bucket do Amazon S3 ou uma função do IAM foi compartilhado com uma entidade externa?

a) AWS Organizations (Organizações da AWS)  
b) **AWS IAM Access Analyzer (Analisador de Acesso do IAM da AWS)**  
c) AWS Service Catalog (Catálogo de Serviços da AWS)  
d) AWS Systems Manager (Gerenciador de Sistemas da AWS)  

**Explicação:**
**Correta:**
- **AWS IAM Access Analyzer (Analisador de Acesso do IAM da AWS)**:
  - O AWS IAM Access Analyzer (Analisador de Acesso do IAM da AWS) ajuda a identificar recursos na sua organização e contas que estão compartilhados com uma entidade externa. Ele analisa as políticas de recursos do IAM e fornece um relatório indicando se um bucket do Amazon S3, uma função do IAM, ou outros recursos foram compartilhados fora da organização.

**Incorretas:**
- AWS Organizations (Organizações da AWS):
  - O AWS Organizations permite gerenciar e consolidar múltiplas contas da AWS dentro de uma organização, mas não fornece funcionalidades específicas para analisar políticas de recursos e identificar compartilhamentos externos.
- AWS Service Catalog (Catálogo de Serviços da AWS):
  - O AWS Service Catalog permite que as organizações criem e gerenciem catálogos de serviços de TI aprovados, mas não fornece funcionalidades para identificar compartilhamentos externos de recursos.
- AWS Systems Manager (Gerenciador de Sistemas da AWS):
  - O AWS Systems Manager ajuda a gerenciar a infraestrutura AWS e local, oferecendo automação, monitoramento e gerenciamento, mas não é usado para identificar compartilhamentos externos de recursos do IAM ou do S3.

---

**Pergunta 38**

Quais das opções a seguir são benefícios de usar o AWS Trusted Advisor? (Escolha dois.)

a) Implementar marcação obrigatória em recursos da AWS  
b) **Detectar recursos subutilizados para economizar custos**  
c) **Melhorar a segurança monitorando proativamente o ambiente AWS**  
d) Fornecer orquestração de contêiner de alto desempenho  
e) Criar e rotacionar chaves de criptografia  

**Explicação:**
**Corretas:**
- **Detectar recursos subutilizados para economizar custos**:
  - O AWS Trusted Advisor analisa o uso dos recursos da AWS e fornece recomendações para otimização de custos, incluindo a identificação de recursos subutilizados. Isso pode ajudar as organizações a economizar dinheiro eliminando recursos desnecessários ou dimensionando recursos de forma mais eficiente.
- **Melhorar a segurança monitorando proativamente o ambiente AWS**:
  - O AWS Trusted Advisor também fornece recomendações de segurança para melhorar a postura de segurança do ambiente AWS. Ele pode detectar configurações incorretas, como portas abertas desnecessárias, políticas de segurança mal configuradas ou configurações que podem expor a infraestrutura a vulnerabilidades. Isso ajuda a aumentar a segurança proativamente, reduzindo o risco de violações de segurança.

**Incorretas:**
- Implementar marcação obrigatória em recursos da AWS:
  - O AWS Trusted Advisor não é uma ferramenta para implementar marcação obrigatória em recursos da AWS. Ele fornece recomendações para otimização de custos, desempenho e segurança, mas não inclui funcionalidades relacionadas à gestão de marcação de recursos.
- Fornecer orquestração de contêiner de alto desempenho:
  - O AWS Trusted Advisor não está diretamente relacionado à orquestração de contêineres. Ele se concentra em fornecer recomendações para otimização de custos, desempenho e segurança dos recursos da AWS.
- Criar e rotacionar chaves de criptografia:
  - Embora a criptografia seja uma prática de segurança importante, o AWS Trusted Advisor não é responsável por criar ou rotacionar chaves de criptografia. Ele fornece recomendações para melhorar a segurança do ambiente AWS, mas não inclui a gestão direta de chaves de criptografia.

---

**Pergunta 39**

Uma empresa está usando uma plataforma central de dados para gerenciar vários tipos de dados de seus clientes. A empresa deseja usar os serviços da AWS para descobrir, transformar e visualizar os dados. Qual combinação de serviços da AWS a empresa deve usar para atender a esses requisitos? (Escolha dois.)

a) **AWS Glue**  
b) Amazon Elastic File System (Amazon EFS)  
c) Amazon Redshift  
d) **Amazon QuickSight**  
e) Amazon Quantum Ledger Database (Amazon QLDB)  

**Explicação:**
**Corretas:**
- **AWS Glue**:
  - O AWS Glue é um serviço de ETL (extração, transformação e carregamento) que ajuda a descobrir, preparar e transformar dados para análise. Ele pode catalogar dados de várias fontes, transformá-los usando jobs de ETL e torná-los disponíveis para análise.
- **Amazon QuickSight**:
  - O Amazon QuickSight é um serviço de BI (business intelligence) que permite criar visualizações e dashboards interativos para analisar dados. Ele pode se conectar a várias fontes de dados, incluindo aquelas preparadas pelo AWS Glue, e permite aos usuários criar relatórios e insights baseados nos dados.

**Incorretas:**
- Amazon Elastic File System (Amazon EFS):
  - O Amazon EFS é um sistema de arquivos para armazenamento compartilhado de dados, mas não oferece funcionalidades para descobrir, transformar ou visualizar dados.
- Amazon Redshift:
  - O Amazon Redshift é um data warehouse na nuvem que permite executar consultas analíticas rápidas em grandes volumes de dados. Embora seja uma ferramenta poderosa para análise de dados, ele não oferece diretamente as capacidades de ETL e visualização que o AWS Glue e o Amazon QuickSight fornecem.
- Amazon Quantum Ledger Database (Amazon QLDB):
  - O Amazon QLDB é um banco de dados de razão imutável e transparente para aplicações que precisam de um log centralizado de transações. Ele não é projetado para ETL ou visualização de dados.

---

**Pergunta 40**

Uma empresa deseja automatizar a aplicação de patches de segurança em suas instâncias do Amazon EC2. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) **AWS Systems Manager**  
b) AWS CloudFormation  
c) AWS CodePipeline  
d) AWS Config  

**Explicação:**
**Correta:**
- **AWS Systems Manager**:
  - O AWS Systems Manager oferece um recurso chamado Patch Manager, que permite automatizar a aplicação de patches de segurança em instâncias do Amazon EC2. Ele pode ser configurado para aplicar patches automaticamente em um cronograma específico, garantindo que as instâncias estejam sempre atualizadas com os últimos patches de segurança.

**Incorretas:**
- AWS CloudFormation:
  - O AWS CloudFormation é um serviço de provisionamento de infraestrutura como código (IaC) que permite criar e gerenciar recursos da AWS usando modelos. Embora seja poderoso para automação de infraestrutura, ele não é projetado especificamente para gerenciar patches de segurança.
- AWS CodePipeline:
  - O AWS CodePipeline é um serviço de integração e entrega contínua (CI/CD) que ajuda a automatizar os pipelines de entrega de software. Ele não é usado para a aplicação de patches de segurança em instâncias do EC2.
- AWS Config:
  - O AWS Config é um serviço que permite avaliar, auditar e monitorar as configurações de recursos da AWS. Embora útil para conformidade e auditoria, ele não oferece recursos para aplicar patches de segurança.

---

**Pergunta 41**

Uma empresa está em processo de migração para a nuvem AWS e deseja obter orientação sobre as melhores práticas de arquitetura, segurança e eficiência de custos. Qual programa ou recurso da AWS a empresa deve utilizar para obter esse tipo de orientação?

a) AWS Service Catalog (Catálogo de Serviços da AWS)  
b) AWS CloudFormation  
c) **AWS Well-Architected Tool**  
d) AWS OpsWorks  

**Explicação:**
**Correta:**
- **AWS Well-Architected Tool**:
  - A AWS Well-Architected Tool é um serviço que ajuda as empresas a revisar suas arquiteturas de workloads e adotar as melhores práticas na nuvem AWS. Ele oferece orientação sobre segurança, eficiência de custos, desempenho, confiabilidade e sustentabilidade, ajudando as empresas a construir sistemas bem projetados na AWS.

**Incorretas:**
- AWS Service Catalog (Catálogo de Serviços da AWS):
  - O AWS Service Catalog permite que as organizações criem e gerenciem catálogos de serviços de TI aprovados para uso em AWS, mas não fornece orientação sobre melhores práticas de arquitetura.
- AWS CloudFormation:
  - O AWS CloudFormation é uma ferramenta de provisionamento de infraestrutura como código (IaC) que permite criar e gerenciar recursos da AWS usando templates. Embora útil para automação de infraestrutura, ele não oferece orientação sobre melhores práticas.
- AWS OpsWorks:
  - O AWS OpsWorks é um serviço de gerenciamento de configuração que fornece automação usando Chef e Puppet. Ele é útil para gerenciamento de configuração e automação de infraestrutura, mas não oferece orientação específica sobre melhores práticas de arquitetura.

---

**Pergunta 42**

Qual pilar do AWS Well-Architected Framework se concentra em proteger informações e sistemas?

a) Sustentabilidade  
b) Confiabilidade  
c) Eficiência de desempenho  
d) **Segurança**  

**Explicação:**
**Correta:**
- **Segurança**:
  - O pilar de Segurança do AWS Well-Architected Framework se concentra em proteger informações e sistemas. Ele cobre áreas como controle de acesso, proteção de dados, resposta a incidentes, segurança de rede e monitoramento de segurança.

**Incorretas:**
- Sustentabilidade:
  - O pilar de Sustentabilidade se concentra em minimizar o impacto ambiental e aumentar a eficiência dos recursos de TI.
- Confiabilidade:
  - O pilar de Confiabilidade se concentra em garantir que uma carga de trabalho execute suas funções pretendidas corretamente e possa se recuperar rapidamente de falhas.
- Eficiência de desempenho:
  - O pilar de Eficiência de Desempenho se concentra em usar recursos de TI de maneira eficiente para atender aos requisitos de sistema e desempenho.

---

**Pergunta 43**

Qual serviço AWS pode ser usado para provisionar clusters de contêineres que executam o Kubernetes?

a) Amazon ECS  
b) Amazon Elastic Beanstalk  
c) **Amazon EKS**  
d) AWS Fargate  

**Explicação:**
**Correta:**
- **Amazon EKS**:
  - O Amazon Elastic Kubernetes Service (EKS) é um serviço gerenciado que facilita a execução do Kubernetes na AWS sem a necessidade de instalar e operar seu próprio plano de controle do Kubernetes.

**Incorretas:**
- Amazon ECS:
  - O Amazon Elastic Container Service (ECS) é um serviço de orquestração de contêineres gerenciado que suporta Docker. Embora poderoso, ele não executa o Kubernetes nativamente.
- Amazon Elastic Beanstalk:
  - O Amazon Elastic Beanstalk é um serviço de implantação e gerenciamento de aplicações que suporta várias plataformas, incluindo Docker, mas não é usado especificamente para provisionar clusters de Kubernetes.
- AWS Fargate:
  - O AWS Fargate é um mecanismo de computação para contêineres que funciona com Amazon ECS e Amazon EKS, permitindo executar contêineres sem gerenciar servidores. No entanto, para clusters de Kubernetes, o serviço específico é o Amazon EKS.

---

**Pergunta 44**

Uma empresa deseja configurar regras de firewall para permitir ou negar o tráfego de entrada e saída de suas instâncias do Amazon EC2. Qual recurso da AWS a empresa deve usar para atender a esse requisito?

a) AWS Shield  
b) **Grupos de segurança da Amazon VPC**  
c) Amazon CloudWatch  
d) AWS Direct Connect  

**Explicação:**
**Correta:**
- **Grupos de segurança da Amazon VPC**:
  - Os Grupos de Segurança da Amazon VPC (Virtual Private Cloud) atuam como firewalls virtuais para controlar o tráfego de entrada e saída das instâncias do Amazon EC2. Eles permitem que os administradores definam regras para permitir ou negar o tráfego com base em endereços IP, portas e protocolos.

**Incorretas:**
- AWS Shield:
  - O AWS Shield é um serviço gerenciado de proteção contra DDoS (Distributed Denial of Service) que ajuda a proteger aplicações hospedadas na AWS. Ele não é usado para configurar regras de firewall para instâncias EC2.
- Amazon CloudWatch:
  - O Amazon CloudWatch é um serviço de monitoramento que permite coletar e rastrear métricas, monitorar logs e configurar alarmes. Ele não é usado para definir regras de firewall.
- AWS Direct Connect:
  - O AWS Direct Connect é um serviço que estabelece uma conexão de rede dedicada entre a infraestrutura local e a AWS. Ele não é usado para configurar regras de firewall.

---

**Pergunta 45**

Uma empresa deseja melhorar a segurança de suas aplicações web protegendo-as contra exploits da web comuns. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Firewall Manager  
b) Amazon GuardDuty  
c) **AWS WAF**  
d) AWS Shield  

**Explicação:**
**Correta:**
- **AWS WAF**:
  - O AWS Web Application Firewall (WAF) é um firewall de aplicação web que ajuda a proteger aplicações web contra exploits da web comuns, como injeção de SQL e ataques de script entre sites (XSS). Ele permite definir regras personalizadas para filtrar o tráfego HTTP/S com base em padrões de solicitação.

**Incorretas:**
- AWS Firewall Manager:
  - O AWS Firewall Manager é um serviço de gerenciamento de segurança que facilita a configuração e o gerenciamento de regras de firewall em várias contas e recursos da AWS. Ele não é um firewall de aplicação web específico.
- Amazon GuardDuty:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento não autorizado. Embora útil para segurança, ele não protege especificamente contra exploits da web comuns.
- AWS Shield:
  - O AWS Shield é um serviço gerenciado de proteção contra DDoS que ajuda a proteger aplicações hospedadas na AWS. Ele não é um firewall de aplicação web e não fornece proteção contra exploits da web comuns.

---

**Pergunta 46**

Uma empresa deseja implantar um aplicativo em contêineres usando serviços gerenciados pela AWS para orquestração de contêineres. Qual combinação de serviços AWS a empresa deve usar para atender a esse requisito?

a) AWS CodePipeline e AWS CodeBuild  
b) AWS Fargate e Amazon RDS  
c) **Amazon ECS e AWS Fargate**  
d) AWS CloudFormation e AWS CodeDeploy  

**Explicação:**
**Correta:**
- **Amazon ECS e AWS Fargate**:
  - O Amazon Elastic Container Service (ECS) é um serviço gerenciado de orquestração de contêineres que suporta Docker. O AWS Fargate é um mecanismo de computação que permite executar contêineres sem gerenciar servidores ou clusters. Juntos, eles proporcionam uma solução totalmente gerenciada para implantar e gerenciar aplicações em contêineres.

**Incorretas:**
- AWS CodePipeline e AWS CodeBuild:
  - AWS CodePipeline e AWS CodeBuild são serviços de integração e entrega contínua (CI/CD) que ajudam a automatizar pipelines de entrega de software. Embora úteis para automação de construção e implantação, eles não são serviços de orquestração de contêineres.
- AWS Fargate e Amazon RDS:
  - AWS Fargate é um mecanismo de computação para contêineres e Amazon RDS é um serviço gerenciado de banco de dados relacional. Embora possam ser usados juntos para hospedar aplicações e bancos de dados, essa combinação não oferece uma solução completa para orquestração de contêineres.
- AWS CloudFormation e AWS CodeDeploy:
  - AWS CloudFormation é uma ferramenta de provisionamento de infraestrutura como código (IaC) e AWS CodeDeploy é um serviço de implantação automatizada. Eles não são serviços de orquestração de contêineres específicos.

---

**Pergunta 47**

Uma empresa precisa gerenciar e auditar as permissões e políticas de segurança associadas a seus recursos da AWS de maneira centralizada. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Secrets Manager  
b) **AWS IAM**  
c) Amazon Cognito  
d) AWS Systems Manager  

**Explicação:**
**Correta:**
- **AWS IAM**:
  - O AWS Identity and Access Management (IAM) é um serviço que permite gerenciar e auditar permissões e políticas de segurança associadas a usuários, grupos e roles. Ele oferece controle centralizado sobre o acesso a recursos da AWS, permitindo definir e aplicar políticas de segurança e auditorias detalhadas.

**Incorretas:**
- AWS Secrets Manager:
  - O AWS Secrets Manager é um serviço que ajuda a proteger e gerenciar segredos, como credenciais de banco de dados e chaves de API, mas não é usado para gerenciar permissões e políticas de segurança de maneira centralizada.
- Amazon Cognito:
  - O Amazon Cognito é um serviço de gerenciamento de identidade para aplicações web e mobile, permitindo autenticação e autorização de usuários. Embora útil para gerenciar usuários de aplicações, ele não fornece controle centralizado sobre permissões e políticas de segurança para recursos da AWS.
- AWS Systems Manager:
  - O AWS Systems Manager ajuda a gerenciar infraestrutura AWS e local, oferecendo automação, monitoramento e gerenciamento. Ele não é específico para gerenciar e auditar permissões e políticas de segurança.

---

**Pergunta 48**

Uma empresa está usando o AWS Lambda para executar funções serverless. A empresa deseja garantir que as funções Lambda estejam seguras e sejam gerenciadas adequadamente. Qual prática recomendada a empresa deve seguir para atender a esse requisito?

a) Aumentar o tempo de execução das funções Lambda  
b) **Usar variáveis de ambiente criptografadas para armazenar segredos**  
c) Configurar as funções Lambda para executar como root  
d) Manter as funções Lambda desatualizadas para evitar mudanças inesperadas  

**Explicação:**
**Correta:**
- **Usar variáveis de ambiente criptografadas para armazenar segredos**:
  - Uma prática recomendada para garantir a segurança das funções AWS Lambda é usar variáveis de ambiente criptografadas para armazenar segredos, como chaves de API e credenciais. Isso ajuda a proteger informações sensíveis contra acessos não autorizados.

**Incorretas:**
- Aumentar o tempo de execução das funções Lambda:
  - Aumentar o tempo de execução das funções Lambda não está diretamente relacionado à segurança e gerenciamento adequado das funções.
- Configurar as funções Lambda para executar como root:
  - Configurar as funções Lambda para executar como root não é uma prática recomendada de segurança, pois pode aumentar o risco de acessos não autorizados e explorações.
- Manter as funções Lambda desatualizadas para evitar mudanças inesperadas:
  - Manter as funções Lambda desatualizadas pode introduzir vulnerabilidades de segurança. É importante manter as funções atualizadas com as últimas melhorias de segurança e correções de bugs.

---

**Pergunta 49**

Uma empresa precisa proteger seus dados em repouso usando um serviço gerenciado pela AWS que facilita o gerenciamento de chaves de criptografia. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Secrets Manager  
b) Amazon Cognito  
c) **AWS Key Management Service (AWS KMS)**  
d) AWS Shield  

**Explicação:**
**Correta:**
- **AWS Key Management Service (AWS KMS)**:
  - O AWS Key Management Service (KMS) é um serviço gerenciado que facilita o gerenciamento de chaves de criptografia usadas para proteger dados em repouso. Ele permite criar, gerenciar e controlar chaves de criptografia usadas para criptografar dados em diversos serviços da AWS.

**Incorretas:**
- AWS Secrets Manager:
  - O AWS Secrets Manager é um serviço que ajuda a proteger e gerenciar segredos, como credenciais de banco de dados e chaves de API. Embora útil para gerenciar segredos, ele não é especificamente um serviço de criptografia de dados em repouso.
- Amazon Cognito:
  - O Amazon Cognito é um serviço de gerenciamento de identidade para aplicações web e mobile, permitindo autenticação e autorização de usuários. Ele não é usado para criptografar dados em repouso.
- AWS Shield:
  - O AWS Shield é um serviço gerenciado de proteção contra DDoS (Distributed Denial of Service) que ajuda a proteger aplicações hospedadas na AWS. Ele não é um serviço de criptografia de dados em repouso.

---

**Pergunta 50**

Uma empresa está implantando um aplicativo de aprendizado de máquina na AWS e precisa de um serviço gerenciado para criar, treinar e implantar modelos de aprendizado de máquina. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) Amazon Comprehend  
b) **Amazon SageMaker**  
c) Amazon Rekognition  
d) AWS DeepRacer  

**Explicação:**
**Correta:**
- **Amazon SageMaker**:
  - O Amazon SageMaker é um serviço gerenciado que permite criar, treinar e implantar modelos de aprendizado de máquina de maneira fácil e escalável. Ele fornece ferramentas e infraestrutura para todo o ciclo de vida do desenvolvimento de modelos de aprendizado de máquina.

**Incorretas:**
- Amazon Comprehend:
  - O Amazon Comprehend é um serviço de processamento de linguagem natural (NLP) que usa aprendizado de máquina para descobrir insights e relacionamentos em textos. Embora útil para análise de texto, ele não é um serviço geral de criação, treinamento e implantação de modelos de aprendizado de máquina.
- Amazon Rekognition:
  - O Amazon Rekognition é um serviço de análise de imagens e vídeos que utiliza aprendizado de máquina para identificar objetos, pessoas, textos, cenas e atividades. Ele não é um serviço para criar, treinar e implantar modelos de aprendizado de máquina personalizados.
- AWS DeepRacer:
  - O AWS DeepRacer é uma plataforma de corrida de carros autônomos em miniatura que permite experimentar aprendizado por reforço. Embora seja uma ferramenta educativa e divertida para aprendizado por reforço, não é um serviço gerenciado para criar, treinar e implantar modelos de aprendizado de máquina em aplicações comerciais.

---

**Pergunta 51**

Uma empresa está migrando suas aplicações legadas para a AWS e deseja obter uma avaliação do custo total de propriedade (TCO) e do retorno sobre o investimento (ROI) da migração. Qual ferramenta AWS a empresa deve usar para obter essas informações?

a) AWS Trusted Advisor  
b) **Calculadora de TCO da AWS**  
c) AWS Artifact  
d) AWS Migration Hub  

**Explicação:**
**Correta:**
- **Calculadora de TCO da AWS**:
  - A Calculadora de TCO da AWS permite que as empresas comparem o custo total de propriedade (TCO) da AWS com o custo de uma solução de infraestrutura local. Ela ajuda a calcular o ROI da migração para a nuvem, fornecendo uma visão clara dos benefícios de custo da migração.

**Incorretas:**
- AWS Trusted Advisor:
  - O AWS Trusted Advisor fornece recomendações para otimização de custos, desempenho, segurança e tolerância a falhas na AWS, mas não é especificamente uma ferramenta para calcular TCO e ROI da migração.
- AWS Artifact:
  - O AWS Artifact é um portal que oferece acesso a relatórios de conformidade e outros documentos relacionados à segurança e conformidade na AWS. Não é usado para calcular TCO e ROI da migração.
- AWS Migration Hub:
  - O AWS Migration Hub ajuda a monitorar o progresso das migrações de aplicações para a AWS, mas não fornece avaliações de TCO e ROI.

---

**Pergunta 52**

Uma empresa deseja melhorar a eficiência do uso de recursos de computação ao executar cargas de trabalho variáveis. Qual recurso do Amazon EC2 a empresa deve usar para ajustar automaticamente a capacidade de computação com base na demanda?

a) Instâncias Spot  
b) **Auto Scaling**  
c) Instâncias Reservadas  
d) AWS Elastic Beanstalk  

**Explicação:**
**Correta:**
- **Auto Scaling**:
  - O Amazon EC2 Auto Scaling ajusta automaticamente a capacidade de computação com base na demanda de suas aplicações, ajudando a manter a performance desejada ao mesmo tempo que otimiza custos. Ele permite adicionar ou remover instâncias EC2 dinamicamente conforme necessário.

**Incorretas:**
- Instâncias Spot:
  - As Instâncias Spot oferecem capacidade de computação não utilizada na AWS a preços reduzidos, mas não fornecem ajuste automático de capacidade com base na demanda.
- Instâncias Reservadas:
  - As Instâncias Reservadas oferecem descontos significativos em troca de um compromisso de uso por um ou três anos. Elas não ajustam automaticamente a capacidade de computação com base na demanda.
- AWS Elastic Beanstalk:
  - O AWS Elastic Beanstalk é um serviço que facilita a implantação e o gerenciamento de aplicações na AWS. Embora ofereça alguma capacidade de escalabilidade automática, o recurso específico para ajustar automaticamente a capacidade de computação com base na demanda é o Auto Scaling.

---

**Pergunta 53**

Uma empresa precisa gerenciar centralmente as permissões de usuários e políticas de segurança para várias contas da AWS em sua organização. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Config  
b) **AWS Organizations**  
c) Amazon GuardDuty  
d) AWS CloudFormation  

**Explicação:**
**Correta:**
- **AWS Organizations**:
  - O AWS Organizations permite gerenciar e consolidar várias contas da AWS em uma organização. Ele oferece controle centralizado sobre permissões e políticas de segurança, facilitando a gestão de usuários e recursos em um ambiente multi-conta.

**Incorretas:**
- AWS Config:
  - O AWS Config monitora e registra continuamente as configurações de recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas. Ele não é usado para gerenciar permissões e políticas de segurança centralmente.
- Amazon GuardDuty:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento não autorizado. Ele não é usado para gerenciar permissões e políticas de segurança.
- AWS CloudFormation:
  - O AWS CloudFormation é uma ferramenta de provisionamento de infraestrutura como código (IaC) que permite criar e gerenciar recursos da AWS usando templates. Embora útil para automação de infraestrutura, ele não oferece funcionalidades específicas para gerenciar permissões e políticas de segurança centralmente.

---

**Pergunta 54**

Qual serviço da AWS pode ser usado para implantar e gerenciar redes de entrega de conteúdo (CDNs) para distribuir conteúdo globalmente com baixa latência?

a) Amazon RDS  
b) Amazon VPC  
c) **Amazon CloudFront**  
d) AWS Direct Connect  

**Explicação:**
**Correta:**
- **Amazon CloudFront**:
  - O Amazon CloudFront é um serviço de rede de entrega de conteúdo (CDN) que distribui conteúdo globalmente com baixa latência. Ele usa uma rede de pontos de presença (PoPs) para armazenar em cache e entregar conteúdo aos usuários de maneira eficiente.

**Incorretas:**
- Amazon RDS:
  - O Amazon RDS é um serviço gerenciado de banco de dados relacional que facilita a configuração, operação e escalabilidade de bancos de dados na nuvem. Ele não é usado para distribuição de conteúdo global.
- Amazon VPC:
  - O Amazon VPC (Virtual Private Cloud) permite provisionar uma seção isolada logicamente da AWS, onde você pode lançar recursos da AWS em uma rede virtual. Ele não é um serviço de entrega de conteúdo.
- AWS Direct Connect:
  - O AWS Direct Connect é um serviço que estabelece uma conexão de rede dedicada entre a infraestrutura local e a AWS. Ele não é usado para implantar e gerenciar redes de entrega de conteúdo.

---

**Pergunta 55**

Uma empresa deseja rastrear e gerenciar seus custos de serviços da AWS com o maior nível de detalhamento possível. Qual serviço ou recurso da AWS a empresa deve usar para atender a esse requisito?

a) AWS Trusted Advisor  
b) **AWS Cost and Usage Report (Relatório de Custos e Uso da AWS)**  
c) AWS Config  
d) AWS Budgets  

**Explicação:**
**Correta:**
- **AWS Cost and Usage Report (Relatório de Custos e Uso da AWS)**:
  - O AWS Cost and Usage Report (CUR) fornece o maior nível de detalhamento sobre custos e uso dos serviços da AWS. Ele permite que as empresas exportem seus dados de faturamento detalhados para um bucket do Amazon S3 para análise detalhada.

**Incorretas:**
- AWS Trusted Advisor:
  - O AWS Trusted Advisor oferece recomendações para otimização de recursos, economia de custos, desempenho, tolerância a falhas e melhorias de segurança, mas não fornece o nível de detalhamento do AWS Cost and Usage Report.
- AWS Config:
  - O AWS Config é um serviço que permite avaliar, auditar e monitorar as configurações de recursos da AWS. Ele não é usado para rastrear e gerenciar custos detalhadamente.
- AWS Budgets:
  - O AWS Budgets permite criar orçamentos personalizados para monitorar custos e uso da AWS e definir alertas quando certos limites são atingidos. Embora útil para controle de custos, ele não fornece o nível de detalhamento do AWS Cost and Usage Report.

---

**Pergunta 56**

Uma empresa precisa proteger suas aplicações web contra ataques DDoS. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS CloudTrail  
b) Amazon Inspector  
c) **AWS Shield**  
d) Amazon GuardDuty  

**Explicação:**
**Correta:**
- **AWS Shield**:
  - O AWS Shield é um serviço gerenciado de proteção contra DDoS (Distributed Denial of Service) que ajuda a proteger aplicações hospedadas na AWS contra ataques DDoS. Ele oferece proteção automática contra o tráfego malicioso que visa sobrecarregar e interromper serviços.

**Incorretas:**
- AWS CloudTrail:
  - O AWS CloudTrail é um serviço que fornece auditoria e monitoramento de atividades em contas da AWS. Embora útil para rastrear ações e mudanças em recursos, ele não é usado especificamente para proteção contra DDoS.
- Amazon Inspector:
  - O Amazon Inspector é um serviço de avaliação de segurança que verifica automaticamente aplicações em busca de vulnerabilidades e desvios das melhores práticas de segurança. Ele não é um serviço de proteção contra DDoS.
- Amazon GuardDuty:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento não autorizado para proteger suas contas e cargas de trabalho da AWS. Embora útil para detecção de ameaças, ele não é especificamente projetado para proteção contra DDoS.

---

**Pergunta 57**

Uma empresa deseja implementar uma política de "least privilege" (menor privilégio) para usuários e serviços em sua conta da AWS. Qual serviço AWS a empresa deve usar para definir e aplicar essas políticas de acesso?

a) Amazon CloudWatch  
b) AWS Systems Manager  
c) **AWS Identity and Access Management (IAM)**  
d) Amazon RDS  

**Explicação:**
**Correta:**
- **AWS Identity and Access Management (IAM)**:
  - O AWS Identity and Access Management (IAM) é o serviço da AWS que permite gerenciar o acesso a serviços e recursos da AWS com segurança. Ele permite definir e aplicar políticas de acesso baseadas no princípio do "least privilege" (menor privilégio), garantindo que os usuários e serviços tenham apenas as permissões necessárias para realizar suas funções.

**Incorretas:**
- Amazon CloudWatch:
  - O Amazon CloudWatch é um serviço de monitoramento que permite coletar e rastrear métricas, monitorar logs e configurar alarmes. Ele não é usado para definir e aplicar políticas de acesso.
- AWS Systems Manager:
  - O AWS Systems Manager ajuda a gerenciar infraestrutura AWS e local, oferecendo automação, monitoramento e gerenciamento. Ele não é usado para definir e aplicar políticas de acesso.
- Amazon RDS:
  - O Amazon RDS é um serviço gerenciado de banco de dados relacional que facilita a configuração, operação e escalabilidade de bancos de dados na nuvem. Ele não é usado para gerenciar políticas de acesso.

---

**Pergunta 58**

Uma empresa deseja usar um serviço AWS para criar e gerenciar chaves de criptografia para proteger seus dados armazenados em serviços da AWS. Qual serviço a empresa deve usar para atender a esse requisito?

a) AWS Secrets Manager  
b) **AWS Key Management Service (KMS)**  
c) Amazon Cognito  
d) AWS Certificate Manager (ACM)  

**Explicação:**
**Correta:**
- **AWS Key Management Service (KMS)**:
  - O AWS Key Management Service (KMS) é um serviço gerenciado que facilita a criação, gerenciamento e controle de chaves de criptografia usadas para proteger dados em serviços da AWS. Ele permite gerenciar chaves de criptografia de forma segura e integrada com outros serviços da AWS.

**Incorretas:**
- AWS Secrets Manager:
  - O AWS Secrets Manager é um serviço que ajuda a proteger e gerenciar segredos, como credenciais de banco de dados e chaves de API. Embora útil para gerenciar segredos, ele não é especificamente um serviço de criptografia de dados.
- Amazon Cognito:
  - O Amazon Cognito é um serviço de gerenciamento de identidade para aplicações web e mobile, permitindo autenticação e autorização de usuários. Ele não é usado para criar e gerenciar chaves de criptografia.
- AWS Certificate Manager (ACM):
  - O AWS Certificate Manager (ACM) facilita o provisionamento, gerenciamento e implantação de certificados SSL/TLS para uso com serviços da AWS e recursos internos conectados à Internet. Embora útil para gerenciar certificados, ele não é usado para criar e gerenciar chaves de criptografia para dados armazenados.

---

**Pergunta 59**

Uma empresa deseja monitorar continuamente suas contas da AWS em busca de atividades maliciosas e comportamento não autorizado. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS CloudTrail  
b) **Amazon GuardDuty**  
c) Amazon Macie  
d) AWS Config  

**Explicação:**
**Correta:**
- **Amazon GuardDuty**:
  - O Amazon GuardDuty é um serviço de detecção de ameaças que monitora continuamente atividades maliciosas e comportamento não autorizado para proteger suas contas e cargas de trabalho da AWS. Ele usa machine learning, análise estatística e feeds de ameaças integrados para identificar e alertar sobre ameaças potenciais.

**Incorretas:**
- AWS CloudTrail:
  - O AWS CloudTrail registra e monitora todas as ações realizadas em contas da AWS, fornecendo um histórico detalhado de chamadas de API. Embora útil para auditoria e rastreamento de atividades, ele não oferece detecção automática de ameaças como o Amazon GuardDuty.
- Amazon Macie:
  - O Amazon Macie é um serviço de segurança que usa machine learning para descobrir, classificar e proteger dados sensíveis na AWS. Ele é focado na proteção de dados e não na detecção de atividades maliciosas em geral.
- AWS Config:
  - O AWS Config monitora e registra continuamente as configurações de recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas. Ele não é usado para detecção de atividades maliciosas.

---

**Pergunta 60**

Uma empresa está usando várias contas da AWS e deseja consolidar o faturamento para obter uma visão geral dos custos e otimizar as despesas. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS CloudFormation  
b) Amazon CloudWatch  
c) **AWS Organizations**  
d) AWS Config  

**Explicação:**
**Correta:**
- **AWS Organizations**:
  - O AWS Organizations permite consolidar várias contas da AWS em uma única organização e gerenciar centralmente políticas e práticas de segurança. Ele também permite consolidar o faturamento, oferecendo uma visão geral dos custos e otimizando as despesas através de descontos em volume e simplificação do gerenciamento financeiro.

**Incorretas:**
- AWS CloudFormation:
  - O AWS CloudFormation é uma ferramenta de provisionamento de infraestrutura como código (IaC) que permite criar e gerenciar recursos da AWS usando templates. Ele não é usado para consolidar o faturamento.
- Amazon CloudWatch:
  - O Amazon CloudWatch é um serviço de monitoramento que permite coletar e rastrear métricas, monitorar logs e configurar alarmes. Ele não oferece funcionalidades para consolidar o faturamento de várias contas.
- AWS Config:
  - O AWS Config monitora e registra continuamente as configurações de recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas. Ele não é usado para consolidar o faturamento.

---

**Pergunta 61**

Uma empresa deseja armazenar dados no Amazon S3 que são raramente acessados, mas precisam estar disponíveis imediatamente quando solicitados. A empresa deseja minimizar os custos de armazenamento. Qual classe de armazenamento S3 a empresa deve usar para atender a esse requisito?

a) S3 Standard  
b) **S3 Standard-Infrequent Access (S3 Standard-IA)**  
c) S3 One Zone-Infrequent Access (S3 One Zone-IA)  
d) S3 Glacier  

**Explicação:**
**Correta:**
- **S3 Standard-Infrequent Access (S3 Standard-IA)**:
  - A classe de armazenamento S3 Standard-IA é projetada para dados que são acessados raramente, mas que precisam estar disponíveis imediatamente quando solicitados. Ela oferece menor custo de armazenamento em comparação com a classe S3 Standard, mas com uma taxa de recuperação de dados.

**Incorretas:**
- S3 Standard:
  - A classe de armazenamento S3 Standard é projetada para dados que são acessados com frequência. Embora ofereça alta disponibilidade e durabilidade, ela é mais cara em comparação com a classe S3 Standard-IA para dados raramente acessados.
- S3 One Zone-Infrequent Access (S3 One Zone-IA):
  - A classe S3 One Zone-IA é mais econômica, mas armazena dados em uma única zona de disponibilidade (AZ), o que pode não atender aos requisitos de disponibilidade imediata em caso de falha na AZ.
- S3 Glacier:
  - O S3 Glacier é uma classe de armazenamento de baixo custo para arquivamento de dados que não precisam ser acessados frequentemente. Os dados armazenados no Glacier não estão disponíveis imediatamente e requerem um tempo de recuperação.

---

**Pergunta 62**

Uma empresa deseja aplicar políticas de segurança que proíbem o uso de determinados serviços da AWS em suas contas. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Identity and Access Management (IAM)  
b) **AWS Organizations**  
c) AWS Config  
d) AWS CloudTrail  

**Explicação:**
**Correta:**
- **AWS Organizations**:
  - O AWS Organizations permite criar e aplicar políticas de controle de serviço (SCPs) que podem proibir ou permitir o uso de determinados serviços da AWS em todas as contas de uma organização. Isso ajuda a garantir que as políticas de segurança e conformidade sejam aplicadas de forma consistente.

**Incorretas:**
- AWS Identity and Access Management (IAM):
  - O AWS IAM permite gerenciar o acesso a serviços e recursos da AWS, mas não oferece a capacidade de aplicar políticas de controle de serviço (SCPs) em toda a organização.
- AWS Config:
  - O AWS Config monitora e registra continuamente as configurações de recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas, mas não aplica políticas de uso de serviços.
- AWS CloudTrail:
  - O AWS CloudTrail registra e monitora todas as ações realizadas em contas da AWS, fornecendo um histórico detalhado de chamadas de API. Ele não é usado para aplicar políticas de uso de serviços.

---

**Pergunta 63**

Uma empresa está desenvolvendo um aplicativo móvel e deseja autenticar os usuários e fornecer autorização com base em funções. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS Directory Service  
b) **Amazon Cognito**  
c) AWS Secrets Manager  
d) AWS Key Management Service (KMS)  

**Explicação:**
**Correta:**
- **Amazon Cognito**:
  - O Amazon Cognito é um serviço que facilita a adição de autenticação, autorização e gerenciamento de usuários a suas aplicações web e mobile. Ele permite autenticar usuários através de provedores de identidade externos ou diretamente no Cognito User Pools e fornecer autorização baseada em funções.

**Incorretas:**
- AWS Directory Service:
  - O AWS Directory Service oferece várias opções para configurar e gerenciar diretórios na nuvem, incluindo Microsoft Active Directory. Embora útil para integração com AD, ele não é otimizado para autenticação de usuários móveis.
- AWS Secrets Manager:
  - O AWS Secrets Manager é um serviço para proteger e gerenciar segredos, como credenciais de banco de dados e chaves de API. Ele não é usado para autenticação e autorização de usuários.
- AWS Key Management Service (KMS):
  - O AWS KMS é um serviço gerenciado para criação e controle de chaves de criptografia usadas para proteger dados na AWS. Ele não fornece funcionalidades de autenticação e autorização de usuários.

---

**Pergunta 64**

Uma empresa deseja monitorar seus recursos da AWS em tempo real, definir alarmes e tomar ações automatizadas com base nas métricas de desempenho. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) AWS CloudTrail  
b) AWS Config  
c) **Amazon CloudWatch**  
d) AWS Lambda  

**Explicação:**
**Correta:**
- **Amazon CloudWatch**:
  - O Amazon CloudWatch é um serviço de monitoramento que permite coletar e rastrear métricas, monitorar logs e definir alarmes para seus recursos da AWS. Ele permite definir ações automatizadas com base em métricas de desempenho, como iniciar ou parar instâncias, enviar notificações e executar funções AWS Lambda.

**Incorretas:**
- AWS CloudTrail:
  - O AWS CloudTrail registra e monitora todas as ações realizadas em contas da AWS, fornecendo um histórico detalhado de chamadas de API. Embora útil para auditoria e rastreamento de atividades, ele não oferece monitoramento em tempo real e definição de alarmes baseados em métricas de desempenho.
- AWS Config:
  - O AWS Config monitora e registra continuamente as configurações de recursos da AWS e permite automatizar a avaliação das configurações registradas em relação às configurações desejadas. Ele não é usado para monitoramento em tempo real e definição de alarmes.
- AWS Lambda:
  - O AWS Lambda é um serviço de computação serverless que permite executar código em resposta a eventos. Embora possa ser usado como parte de uma ação automatizada definida no CloudWatch, ele não é um serviço de monitoramento em si.

---

**Pergunta 65**

Uma empresa deseja armazenar logs de auditoria por um longo período para fins de conformidade e precisa garantir que os dados estejam disponíveis e imutáveis. Qual serviço AWS a empresa deve usar para atender a esse requisito?

a) Amazon RDS  
b) Amazon S3 Standard  
c) **Amazon S3 Glacier Deep Archive**  
d) AWS CloudTrail  

**Explicação:**
**Correta:**
- **Amazon S3 Glacier Deep Archive**:
  - O Amazon S3 Glacier Deep Archive é uma classe de armazenamento de baixo custo projetada para dados raramente acessados que precisam ser armazenados por longos períodos. Ele oferece imutabilidade e alta durabilidade, tornando-o ideal para armazenar logs de auditoria para fins de conformidade.

**Incorretas:**
- Amazon RDS:
  - O Amazon RDS é um serviço gerenciado de banco de dados relacional que facilita a configuração, operação e escalabilidade de bancos de dados na nuvem. Ele não é otimizado para armazenamento de logs de auditoria de longo prazo.
- Amazon S3 Standard:
  - A classe de armazenamento Amazon S3 Standard é projetada para dados frequentemente acessados e oferece alta durabilidade e disponibilidade. Embora possa ser usada para armazenar logs, ela não é a opção mais econômica para armazenamento de longo prazo em comparação com o S3 Glacier Deep Archive.
- AWS CloudTrail:
  - O AWS CloudTrail registra e monitora todas as ações realizadas em contas da AWS, fornecendo um histórico detalhado de chamadas de API. Embora útil para auditoria e rastreamento de atividades, ele não oferece armazenamento otimizado para logs de longo prazo como o S3 Glacier Deep Archive.

---
